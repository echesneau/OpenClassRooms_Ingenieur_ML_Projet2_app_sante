# %% [markdown]
# # Projet 2: Concevez une application au service de la santé publique

# %% [markdown]
# ## Notebook de nettoyage des données

# %% [markdown]
# ### chargement des modules Python

# %%
import os
import pandas as pd
import numpy as np
import validators # to check url format
import urllib.request # to check if url is reachable
from deep_translator import GoogleTranslator # to translate
import pycountry # to obtain a list of countries
import unidecode 
import pickle
# To activate if necessary
#from joblib import Parallel, delayed

# %% [markdown]
# ### Fonctions utiles

# %% [markdown]
# #### fonctions d'affichage

# %%
def print_random(data, n):
    """
    function to print n random rows in the dataframe
    parameters : data : pd.DataFrame
                 n : int
    returns : None
    """
    i = np.random.randint(0, len(data), size=n)
    print(data.iloc[i])

# %% [markdown]
# #### Fonctions pour la variable code

# %%
def clean_code(value, verbose=1):
    """
    Function to clean the code of products of Open Food Facts
    return a code of 0 for wrong values
    
    Parameters : value : str or int or float
                    Value to clean
                 verbose : int [0,1], default = 1
                     Verbose level : 0 quiet
                                     1 print modified value
    
    Returns : str  
    """
    val = np.NaN
    done = False
    if type(value) == str :
        if value.isdigit():
            val = value
            done = True
    elif type(value) == float :
        if value.is_integer():
            val = str(int(value))
            done = True
    elif type(value) == int:
        print(value)
        val = str(value)
        done = True
    else :
        print(f"I do not know how to process type {type(value)}")
        
    if verbose == 1 and not done and pd.notnull(value):
        print(f"{value} is not a integer")
    
    return val
    #l_val = len(val)
    #return "0"*(13-l_val)+val

# %% [markdown]
# #### fonctions pour les url

# %%
def clean_url(url, code, verify_exists=False, verbose=1):
    """
    Function to clean the url of products of Open Food Facts
    Verify is the url is in a good format and exists
    Verify if the code product of the url is the code product 
    return NaN for wrong url
    
    Parameters : url : str
                    Value to clean
                 code : str
                     code of products
                 verbose : int [0,1], default = 1
                     Verbose level : 0 quiet
                                     1 print modified value
    
    Returns : url 
    """
    def url_reachable(url):
        try :
            code = urllib.request.urlopen(url).getcode()
        except :
            code = 0
        return code == 200
    
    def url_code(url) :
        name = url.replace("http://world-fr.openfoodfacts.org/", '')
        code = name.split("/")
        if len(code) > 0:
            return code[1]
        else :
            return "0"
        
    if len(url) != len(code): # shape checking
        raise Exceptions("Error in input shape parameters")      
        
    url_clean = []
    for i in range(0, len(url)):
        val = str(url.iloc[i])
        if validators.url(val) : # good format
            if url_code(val) == code.iloc[i] :
                if verify_exists : 
                    if url_reachable(val) : # url reachable
                        url_clean.append(val)
                    else: 
                        if verbose == 1 :
                            print(f"{val} is not reachable")
                        url_clean.append(np.NaN)
                else :
                    url_clean.append(val)
            else :
                if verbose ==1: 
                    print(f"the code of url {val} is not the product code {code.iloc[i]}")
                url_clean.append(np.NaN)
        else :
            #print(val, pd.notnull(val), type(val))
            if verbose == 1 and (pd.notnull(val) and val != "nan"):
                print(f"{val} not in a good format")
            url_clean.append(np.NaN)
    return url_clean

# %%
def clean_url_para(url, code, verify_exists=False):
    """
    same function than clean_url but using joblib.Parallel

    Parameters : url : str
                    Value to clean
                 code : str
                     code of products
                 verbose : int [0,1], default = 1
                     Verbose level : 0 quiet
                                     1 print modified value
    
    Returns : url 
    """
    def do_one(val, code, i, i_tot):
        def url_code(url) :
            name = url.replace("http://world-fr.openfoodfacts.org/", '')
            code = name.split("/")
            if len(code) > 0:
                return code[1]
            else :
                return "0"

        def url_reachable(url):
            try :
                code = urllib.request.urlopen(url).getcode()
                #print(code)
            except :
                code = 0
            if code == 0 :
                try :
                    code = urllib.request.urlopen(url).getcode()
                except :
                    code = 0
            return code == 200
            
        print(f"step = {i}/{i_tot} : {i/i_tot*100:.2f}%", end="\r")
        # To obtain a good result, it is necessary to add these lines
        # I do not know why => investigations...
        try :
            urllib.request.urlopen(val).getcode()
        except :
            pass
        
        if validators.url(val) : # good format
            if url_code(val) == code :
                if verify_exists :
                    if url_reachable(val) : # url reachable
                        #return [i, val]
                        return val
                    else: 
                        #return [i, np.NaN]
                        return np.NaN
                else :
                    #return [i,val]
                    return val
            else :
                #return [i, np.NaN]
                return np.NaN
        else :
            #return [i,np.NaN]
            return np.NaN
        
            
    if len(url) != len(code): # shape checking
        raise Exceptions("Error in input shape parameters")      
    # Checkpoint     
    i = np.arange(0,len(url), round(len(url)/20))
    i[-1] = len(url)
    
    all = []
    for j in range(1, len(i)) :
        result = Parallel(n_jobs=4, verbose=10)(delayed(do_one)(str(url.iloc[i]), code.iloc[i], i, len(url)) for i in range(i[j-1], i[j]))
        all += result
        result = np.array(result)
        with open("list_url_"+str(i[j-1])+'-'+str(i[j])+".pkl", "wb") as ofile :
            pickle.dump(result, ofile)
    all = np.array(all)
    with open("list_url_all.pkl", "wb") as ofile :
        pickle.dump(all, ofile)
    #return all[:,1]
    return all

# %% [markdown]
# #### fonctions pour les str

# %%
def is_str(value, min_size=0):
    """
    function to check if the value is a string with minimum characters
    parameters : value
                    Value to check
                 min_size : int
                    Minimun number of char
    returns : str if value is a str with enough char
              np.NaN else
    """
    if type(min_size) != int :
        try : 
            min_size = int(min_size)
        except :
            min_size = 0
        print(f"Warning : min_size is not a integer, reset to {min_size}")
    if type(value) == str and len(value) >= min_size :
        return value
    else :
        if pd.notnull(value) :
            print(f"{value} is not correct value => ignored")
        return np.NaN

# %%
def str_replace(value, in_motif, out_motif) :
    """
    function to modify str chains to replace in_motif by out_motif
    if the type of value is not str, return numpy.NaN
    
    parameters : value : str
    
    returns : str
    """
    if type(value) == str :
        return value.replace(in_motif, out_motif)
    elif pd.notnull(value) :
        print(f"Type of {value} is {type(value)} : not expected => ignored ")
        return np.NaN
    else :
        return np.NaN

# %%
def remove_str(value, remove_value) :
    """
    function to remove value with a specific str
    parameters : value : str
                 remove_value : str
    return str or np.NaN
    """
    if type(value) == str and value == remove_value:
        return np.NaN
    else :
        return value

# %%
def remove_underscore_start_end(value):
    """
    function to modify str chains to remove _ at the beginning and the end of the str
    if the type of value is not str, return numpy.NaN
    
    parameters : value : str
    
    returns : str
    """
    if type(value) == str :
        return value.rstrip('_').lstrip('_')
    else :
        return np.NaN

# %%
def lower_case(value):
    """
    function to modify str chains to lower case
    if the type of value is not str, return numpy.NaN
    
    parameters : value : str
    
    returns : str.lower()
    """
    if type(value) == str :
        return value.lower()
    elif pd.notnull(value) :
        print(f"Type of {value} is {type(value)} : not expected => ignored ")
        return np.NaN
    else : 
        return np.NaN

# %%
def remove_accent(value) :
    """
    function to remove accents from str value
    parameters : value str
    return : str 
    """
    if type(value) == str :
        return unidecode.unidecode(value)
    elif pd.notnull(value) :
        print(f"Type of {value} is {type(value)} : not expected => ignored")
        return np.NaN
    else :
        return np.NaN

# %%
def str_in(value, motifs, ignore_case = False):
    """
    function to check if a value is in a list of motif
    if yes, return the value,
    else, return NaN
    
    parameters : value : str
                 motifs: list of str
                 ignore_case : bool
                 
    returns : str
    """
    if type(value) == str :
        if ignore_case :
            motifs = list([val.lower() for val in motifs])
            value = value.lower()
        
        if value in motifs :
            return value.lower()
        else : 
            print(f"{value} is not a correct value: ignored")
            return np.NaN
    else :
        return np.NaN

# %%
def find_country(sentence, countries) :
    """
    Function to find a country in a sentence
    return the country found or np.NaN
    
    parameters : sentence : str 
                 country : dict 
                     dict with countries name in different languages
    
    returns : str or np.NaN
    """
    if type(sentence) == str :
        # lower case
        #sentence = sentence.lower()
        # remove accent
        #sentence = unidecode.unidecode(sentence)
        
        #looking for all the sentence in country list
        i_country = list([countries[language].index(sentence) 
                    for language in countries if sentence in countries[language] ] )
        
        words = sentence.split(" ")
        ## lower case
        #words = list(map(lower_case, words))
        ## remove accent
        #words = list(map(unidecode.unidecode, words))
        if len(words) > 1 :
            i_country += list([countries[language].index(word) 
                               for word in words for language in countries 
                               if word in countries[language] ] )
        #print(sentence)
        #print(i_country)
        i_country = list(set(i_country))
        #print(i_country)
        if len(i_country) == 1 :
            country = countries["en"][i_country[0]]
            return country
        elif len(i_country) > 1:
            # if more than one contry, return a list of country split by ","
            #print(f"More than one country found in : {sentence}")
            return ','.join([countries["en"][i_country[i]] for i in range(0, len(i_country)) ] )
        elif '-' in sentence :
            country = find_country(str_replace(sentence, '-', ' '), countries)
            return country
        else :
            # try to replace "-" by space
            print(f"No country detected in {sentence}")
            return np.NaN
    else :
        return np.NaN

# %% [markdown]
# #### fonctions pour les variables float

# %%
def is_float(value) :
    """
    function to verify if a value is a float
    if yes, return the float, else return numpy.NaN

    parameters : value 
    
    returns : float
    """
    try :
        return float(value)
    except ValueError :
        print(f"{value} is not a float")
        return np.NaN

# %%
def is_lower(value, target=np.inf) :
    """
    function to verify if the value is lower than the target value
    parameters : value : float 
                 target : float
    returns : value if the value is lower than the target,
              np.NaN if the value is higher
    """
    if pd.notnull(value) :
        if value <= target :
            return value
        else :
            print(f"{value} is higher than the target {target}")
            return np.NaN
    else :
        return np.NaN

# %%
def is_higher(value, target=-np.inf) :
    """
    function to verify if the value is higher than the target value
    parameters : value : float 
                 target : float
    returns : value if the value is higher than the target,
              np.NaN if the value is lower
    """
    if pd.notnull(value) :
        if value >= target :
            return value
        else :
            print(f"{value} is lower than the target {target}")
            return np.NaN
    else :
        return np.NaN

# %% [markdown]
# #### fonctions pour les variables int

# %%
def is_int(value) :
    """
    function to verify if a value is a int
    if yes, return the int, else, return np.NaN
    parameters : value
    return int
    """
    if pd.isnull(value) :
        return np.NaN
    elif type(value) == int :
        return value
    elif type(value) == float :
        if value.is_integer():
            return int(value)
        else :
            print(f"{value} is not an integer, round to {int(round(value))}")
            return int(round(value))
    elif type(value) == str :
        if value.isdigit() :
            return int(value)
        else :
            print(f"{value} is not a interger => ignored ")
            return np.NaN
    else :
        print(f"Unknown format {type(value)} => ignored")
        return np.NaN

# %% [markdown]
# #### fonctions pour les variables list

# %%
def create_list(value) :
    """
    function to create list from str chains,
    if the type of value is not str, return empty list
    
    parameters : value : str
    
    returns : list
    """
    if type(value) == str :
        return value.split(',')
    elif (type(value) == int or type(value) == float) and pd.notnull(value) :
        print(f"Type of {value} is {type(value)} : not expected => ignored ")
        return []
    else :
        return []

# %%
def list2str(value) :
    """
    function to convert a list to a str with the join function
    parameters : value : str
    return : str if the type of value is list, np.NaN else
    """
    if type(value) == list :
        return ",".join(value)
    else :
        return np.NaN

# %%
def list_replace(values, in_motif, out_motif) :
    """
    function to modify list of str chains to replace in_motif by out_motif in each items
    if the type of value is not list, return empty list
    
    parameters : values : list
    
    returns : list
    """
    out = []
    if type(values) == list :
        for value in values :
            out.append(str_replace(value, in_motif, out_motif))
    return out

# %% [markdown]
# #### fonctions pour la traduction

# %%
def translate_list(values, to='en') :
    """
    function to translate all values of a list to the specific language
    
    parameters : value : list of str
                 
    returns : list of str 
    """
    translated = []
    for value in values :
        source_language = 'auto'
        val = value.split(':')
        if len(val[0]) == 2 and val[0] != "xx" : # xx : unknown country
            source_language = val[0]
        else :
            print(f"Unknown language {val}")
        text = ":".join(val[1:]) # remove the language
        if source_language != to :
            print(text, source_language)
            try : 
                translated.append(GoogleTranslator(source=source_language, 
                                                   target=to).translate(text))
            except :
                translated.append(GoogleTranslator(source='auto', 
                                                   target=to).translate(text))
            print(translated[-1])
        else :
            translated.append(text)
    return translated

# %%
def create_translate_dict(lvalues, to='en', old=None) :
    """
    To create a dict of values to translate from a list of lists (one list per row)
    parameters : list of lists ( [ [values_1] ... [values_n] ] )
                    each value should have a specific format : language:text
    returns : dict 
                { language: [text] }
    """
    if not old is None and type(old) == dict :
        to_translate = old
    else :
        to_translate = {}
    for row in lvalues :
        for value in row :
            source_language = 'auto'
            val = value.split(':')
            if len(val) == 1 :
                text = val[0]
            elif len(val) == 0 :
                text = ''
            else :
                if len(val[0]) == 2 and val[0] != "xx" : # xx : unknown country
                    source_language = val[0]
                else :
                    print(f"Unknown language {val}")
                text = ":".join(val[1:]) # remove the language
            if source_language != to and len(text) > 1 and not text.isdigit(): 
                if not source_language in to_translate :
                    to_translate[source_language] = []
                if not text in to_translate[source_language] :
                    to_translate[source_language].append(text)
    return to_translate

# %%
def translate_dict(to_translate, to='en', old=None) :
    """
    function to translate texts
    
    parameters : to_translate : dict
                    dict[language] = [text]
                 to : target language
                 old : dict 
                     previous translation
    returns : translated : dict
                dict[language] = [translated_text]
    """
    if not old is None and type(old) == dict :
        translated = old
    else :
        translated = {}
    for language in to_translate :
        print(f"Translation of {language} in progress")
        if not language in translated :
            translated[language] = []
        texts = to_translate[language][len(translated[language]) : ]
        if language != 'auto' :
            if len(texts) > 0 :
                try : 
                    translated[language] += GoogleTranslator(source=language, target=to).translate_batch(texts)
                except :
                    print(f"Failed to translate {language}")
                    del to_translate[language][-len(texts):]
        else :
            for word in texts :
                translated[language].append(GoogleTranslator(source=language, target=to).translate(word))
        print("Done")
    return translated

# %%
def apply_translation(values, to_translate, translated, to='en'):
    """
    function to apply the translation 
    
    parameters : values : list
                    list of str
                 to_translate : dict
                     dict of text not translated
                 translated : dict
                     dict of text translated
                 to : str
                     target language
    """
    out = []
    for value in values :
        source_language = 'auto'
        val = value.split(':')
        if len(val) == 1 :
            text = val[0]
        elif len(val) == 0 :
            text = ''
        else :
            if len(val[0]) == 2 and val[0] != "xx" : # xx : unknown country
                source_language = val[0]
            text = ":".join(val[1:]) # remove the language
        if len(text) > 1 :
            if source_language != to :
                if source_language in translated and text in to_translate[source_language] :
                    out.append(translated[source_language][to_translate[source_language].index(text)])
                else :
                    print(f"Failed to translate {text} with original language {source_language}")
            else :
                out.append(text)
        else :
            print(f"Value of text is strange : {text} => ignored")
    return out

# %% [markdown]
# #### Fonctions de gestion des doublons

# %%
def merge_rows(rows):
    """
    function to merge n rows identify as duplicated
    parameters : DataFrame with n rows
    returns : DataFrame with 1 row
    """
    def merge_str(values) :
        #remove null values
        names = list([value for value in values if pd.notnull(value) ])
        if len(names) == 0 :
            return np.NaN
        else :
            return ','.join(names)
        
    def merge_float(values) :
        # remove null
        values = list([value for value in values if pd.notnull(value)])
        if len(values) == 0 :
            return np.NaN
        else :
            return np.mean(values)
        
    def merge_list(values) :
        #print("init values")
        #print(values)
        new_l = []
        for value in values :
            new_l += value
        #print("summed values")
        #print(new_l)
        #print("unique value")
        #print(list(set(new_l)))
        return list(set(new_l)) # remove same values
    
    def merge_grade(values) :
        alphabet = ['a','b','c','d','e']
        i_values = list([alphabet.index(value) for value in values 
                   if pd.notnull(value) ] )
        if len(i_values) == 0 :
            return np.NaN
        else :
            return alphabet[round(np.mean(i_values))] 
        
    accepted_columns = ['code','url','product_name', "categories_tags", "nutrition_grade_fr",
                        'carbon-footprint_100g',"origins_tags", "manufacturing_places_tags"
                       ]
    #new_row = pd.DataFrame(columns=rows.columns)
    new_row = {}
    for col in rows.columns :
        if col in accepted_columns :
            if col == "code" : # all codes should be equal
                new_row['code'] = [rows['code'].iloc[0]]
            elif col == 'url' : # first value not null
                urls = rows[pd.notnull(rows["url"])]
                if len(urls) > 0 :
                    new_row['url'] = [urls.iloc[0]['url']]
                else :
                    new_row["url"] = [np.NaN]
            elif col == "product_name": #product names are concatenate
                #names = [rows.iloc[i]["product_name"] for i in range(0,len(rows)) 
                #         if pd.notnull(rows.iloc[i]["product_name"])]
                #new_row["product_name"] = ",".join(names)
                new_row['product_name'] = [ merge_str(rows["product_name"].values) ]
            elif col == "categories_tags": # Categories are merge in a single list
                new_row['categories_tags'] = [ merge_list(rows["categories_tags"].values) ]
            elif col == "origins_tags":
                new_row['origins_tags'] = [ merge_list(rows["origins_tags"].values) ]
            elif col == "manufacturing_places_tags" :
                new_row['manufacturing_places_tags'] = [merge_list(rows["manufacturing_places_tags"].values)]
            elif col == "nutrition_grade_fr": # return the average of grades
                new_row["nutrition_grade_fr"] = [ merge_grade(rows["nutrition_grade_fr"].values) ]
            elif col == "carbon-footprint_100g":
                new_row["carbon-footprint_100g"] = [ merge_float(rows['carbon-footprint_100g'].values) ]
        else :
            print(f"columns name {col} is not known, the value of the first row used. Please update the function")
            new_row[col] = [rows.iloc[0][col]]
    return pd.DataFrame(new_row)

# %% [markdown]
# ### Variables globales

# %%
# PATH os the original database
DATA_FILE = "fr.openfoodfacts.org.products.csv"

COUNTRIES = {}
# List of countries obtained from the pycountry module
COUNTRIES["en"] = list([str_replace(country.name.lower(), ' ', '-') 
                        for country in pycountry.countries]) 

# Some country have a "," in the name, we keep only the first part
COUNTRIES['en'] = list([ country.split(',')[0] for country in COUNTRIES['en'] ])
#for country in COUNTRIES['en'] :
#    country = country.split(',')
#    if len(country) > 1 :
#        print(country)

# Translate country names in different languages
for language in ['fr', 'es', 'de'] :
    COUNTRIES[language] = GoogleTranslator(source="en", target=language).translate("\n".join(COUNTRIES['en'])).split('\n')
    # Put all letters in lower case
    COUNTRIES[language] = list(map(lower_case, COUNTRIES[language]))
    # remove accent 
    COUNTRIES[language] = list(map(unidecode.unidecode, COUNTRIES[language]))
    
# add abreviation
COUNTRIES["alpha_3"] = list([country.alpha_3.lower() for country in pycountry.countries]) 
# replace GBR by uk, often found in the database
COUNTRIES["alpha_3"][COUNTRIES["alpha_3"].index("gbr")] = 'uk'

# The tranlation in french add sometime "le" or "la" or "l'"
# We remove it
COUNTRIES['fr'] = list([str_replace(country, 'la ', '') for country in COUNTRIES['fr']])
COUNTRIES['fr'] = list([str_replace(country, 'le ', '') for country in COUNTRIES['fr']])
COUNTRIES['fr'] = list([str_replace(country, "l'", '') for country in COUNTRIES['fr']])

# add by hand some country or region often found in the list but not in the country list
for country in [{'en': 'european union', 'fr': 'union europeenne', 'es': 'union europea', 
                 'de': 'europaische union', 'alpha_3': 'ue'},
               {'en': 'england', 'fr': 'angleterre', 'es': 'inglaterra', 'de': 'england', 'alpha_3': 'eng'},
               {'en': 'scotland', 'fr': 'ecosse', 'es': 'escocia', 'de': 'schottland', 'alpha_3': 'sco'},
               {'en': 'czech republic', 'fr': 'republique tcheque', 'es': 'republica checa', 
                'de': 'tschechien', 'alpha_3': 'cze2'}, # it should be better to say it equal to czechia
               {'en': 'russia', 'fr': 'russie', 'es': 'rusia', 'de': 'russland', 
                'alpha_3': 'rus2'} # it should be better to say it equal to russian federation
               ]:
    COUNTRIES['en'].append(country['en'])
    COUNTRIES['fr'].append(country['fr'])
    COUNTRIES['es'].append(country['es'])
    COUNTRIES['de'].append(country['de'])
    COUNTRIES['alpha_3'].append(country['alpha_3'])

# Remove translation errors...
# -Turkey is not dinde in french !
i = COUNTRIES['alpha_3'].index("tur")
COUNTRIES['fr'][i] = "turquie"
   
# Verify if country in the list
i = COUNTRIES['alpha_3'].index("tur")
print(COUNTRIES['en'][i])
print(COUNTRIES['fr'][i])
i = COUNTRIES['alpha_3'].index("cze")
print(COUNTRIES['en'][i])
print(COUNTRIES['fr'][i])
i = COUNTRIES['alpha_3'].index("ltu")
print(COUNTRIES['en'][i])
print(COUNTRIES['fr'][i])
i = COUNTRIES['alpha_3'].index("rus")
print(COUNTRIES['en'][i])
print(COUNTRIES['fr'][i])
i = COUNTRIES['alpha_3'].index("zaf")
print(COUNTRIES['en'][i])
print(COUNTRIES['fr'][i])
# Out:
# turkey
# turquie
# czechia
# tchequie
# lithuania
# lituanie
# russian-federation
# federation russe
# south-africa
# afrique du sud

# %% [markdown]
# ### Chargement du dataset

# %%
if os.path.isfile(DATA_FILE):
    DATA = pd.read_csv(DATA_FILE, sep='\t', low_memory=False)
    size = len(DATA)
    n_variables = len(DATA.columns)
    print(f"Taille de l'échantillon = {size}")
    print(f"Nombre de variables     = {n_variables}")
    print("list of variables :")
    print(sorted(list(DATA.columns)))
else :
    print("Error: " + DATA_FILE + " is not a file")
# Out:
# Taille de l'échantillon = 320772
# Nombre de variables     = 162
# list of variables :
# ['additives', 'additives_fr', 'additives_n', 'additives_tags', 'alcohol_100g', 'allergens', 'allergens_fr', 'alpha-linolenic-acid_100g', 'arachidic-acid_100g', 'arachidonic-acid_100g', 'behenic-acid_100g', 'beta-carotene_100g', 'bicarbonate_100g', 'biotin_100g', 'brands', 'brands_tags', 'butyric-acid_100g', 'caffeine_100g', 'calcium_100g', 'capric-acid_100g', 'caproic-acid_100g', 'caprylic-acid_100g', 'carbohydrates_100g', 'carbon-footprint_100g', 'casein_100g', 'categories', 'categories_fr', 'categories_tags', 'cerotic-acid_100g', 'chloride_100g', 'chlorophyl_100g', 'cholesterol_100g', 'chromium_100g', 'cities', 'cities_tags', 'cocoa_100g', 'code', 'collagen-meat-protein-ratio_100g', 'copper_100g', 'countries', 'countries_fr', 'countries_tags', 'created_datetime', 'created_t', 'creator', 'dihomo-gamma-linolenic-acid_100g', 'docosahexaenoic-acid_100g', 'eicosapentaenoic-acid_100g', 'elaidic-acid_100g', 'emb_codes', 'emb_codes_tags', 'energy-from-fat_100g', 'energy_100g', 'erucic-acid_100g', 'fat_100g', 'fiber_100g', 'first_packaging_code_geo', 'fluoride_100g', 'folates_100g', 'fructose_100g', 'fruits-vegetables-nuts_100g', 'gamma-linolenic-acid_100g', 'generic_name', 'glucose_100g', 'glycemic-index_100g', 'gondoic-acid_100g', 'image_small_url', 'image_url', 'ingredients_from_palm_oil', 'ingredients_from_palm_oil_n', 'ingredients_from_palm_oil_tags', 'ingredients_text', 'ingredients_that_may_be_from_palm_oil', 'ingredients_that_may_be_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil_tags', 'iodine_100g', 'iron_100g', 'labels', 'labels_fr', 'labels_tags', 'lactose_100g', 'last_modified_datetime', 'last_modified_t', 'lauric-acid_100g', 'lignoceric-acid_100g', 'linoleic-acid_100g', 'magnesium_100g', 'main_category', 'main_category_fr', 'maltodextrins_100g', 'maltose_100g', 'manganese_100g', 'manufacturing_places', 'manufacturing_places_tags', 'mead-acid_100g', 'melissic-acid_100g', 'molybdenum_100g', 'monounsaturated-fat_100g', 'montanic-acid_100g', 'myristic-acid_100g', 'nervonic-acid_100g', 'no_nutriments', 'nucleotides_100g', 'nutrition-score-fr_100g', 'nutrition-score-uk_100g', 'nutrition_grade_fr', 'nutrition_grade_uk', 'oleic-acid_100g', 'omega-3-fat_100g', 'omega-6-fat_100g', 'omega-9-fat_100g', 'origins', 'origins_tags', 'packaging', 'packaging_tags', 'palmitic-acid_100g', 'pantothenic-acid_100g', 'ph_100g', 'phosphorus_100g', 'pnns_groups_1', 'pnns_groups_2', 'polyols_100g', 'polyunsaturated-fat_100g', 'potassium_100g', 'product_name', 'proteins_100g', 'purchase_places', 'quantity', 'salt_100g', 'saturated-fat_100g', 'selenium_100g', 'serum-proteins_100g', 'serving_size', 'silica_100g', 'sodium_100g', 'starch_100g', 'states', 'states_fr', 'states_tags', 'stearic-acid_100g', 'stores', 'sucrose_100g', 'sugars_100g', 'taurine_100g', 'traces', 'traces_fr', 'traces_tags', 'trans-fat_100g', 'url', 'vitamin-a_100g', 'vitamin-b12_100g', 'vitamin-b1_100g', 'vitamin-b2_100g', 'vitamin-b6_100g', 'vitamin-b9_100g', 'vitamin-c_100g', 'vitamin-d_100g', 'vitamin-e_100g', 'vitamin-k_100g', 'vitamin-pp_100g', 'water-hardness_100g', 'zinc_100g']

# %% [markdown]
# La base de données comporte un grand nombre d'échantillons et de variables.
# Il est nécessaire de sélectionner uniquement les variables utiles à l'application.
# Il est à noter que la page web d'openfoodfacts regroupant les variables n'est pas à jour :
# - certaines variables dans la base de données ne sont pas indiquées
# - à l'invserse, certaines variables sur la page web ne sont pas dans la base de données

# %% [markdown]
# ### Sélection des colonnes
# On créé une nouvelle variable avec uniquement les colonnes utiles à l'application après vérification que la colonne existe.
# Les colonnes sélectionnées permettent de :
# - définir le produit : code, product_name,  categories_tags
# - donner aux utilisateurs l'ensemble des informations via l'url
# - caractériser son origine : manufacturing_place_tags, origins_tags
# - caractériser si il est sein ou non : nutrition_grade_fr
# - caractériser son empreinte_carbone : carbon-footprint_100g
#
# L'analyse univariée avec ces variables a montré que trop peu de produits sont complétement renseignés.
# Le choix a été fait de choisir de nouvelles variables avec un taux de remplissage important (testé dans le notebook d'analyse).
# Les nouvelles variables sont :
# - additives_n (nombre d'additifs)
# - energy_100 (apport calorifique)
# - fat_100g (proportion de graisse)
# - saturated-fat_100g (proportion de graisses saturées)
# - fruits-vegetables-nuts_100g (proportion de fruits et légumes)
# - sodium_100g (teneur en sel)
# - sugars_100g (teneur en sucre)
#
# Les variables pnns_groups_1 et pnns_groups_2 catégorisent également les produits. Elles ne sont pas répertoriées sur le site OpenFoodFact, mais semble intéressantes.

# %%
# colonnes souhaitées
selected_columns = ['code','url','product_name', "categories_tags", "nutrition_grade_fr",
                    'carbon-footprint_100g',"origins_tags", "manufacturing_places_tags",
                    'additives_n', 'energy_100g', 'fat_100g', 'saturated-fat_100g', 
                    'fruits-vegetables-nuts_100g', 'sodium_100g', 'sugars_100g',
                    'pnns_groups_1', 'pnns_groups_2'
                    ]
    
# Identification des colonnes introuvables
i_remove = []
for i, val in enumerate(selected_columns):
    if val not in DATA.columns:
        print(f"Wrong columns name : {val}")
        i_remove.append(i)
        
# Suppression des colonnes introuvables      
for i in i_remove[::-1]:
    del selected_columns[i]
print("Used columns = ")
print(selected_columns)

#Creation d'un DataFrame vide que l'on va remplir ensuite
DATA_CLEANED = pd.DataFrame(columns=selected_columns)
# Out:
# Used columns =
# ['code', 'url', 'product_name', 'categories_tags', 'nutrition_grade_fr', 'carbon-footprint_100g', 'origins_tags', 'manufacturing_places_tags', 'additives_n', 'energy_100g', 'fat_100g', 'saturated-fat_100g', 'fruits-vegetables-nuts_100g', 'sodium_100g', 'sugars_100g', 'pnns_groups_1', 'pnns_groups_2']

# %% [markdown]
# ### Nettoyage du code produit
# Le code doit comporter que des chiffres
# Seul les valeurs aberrantes sont affichées

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["code"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 23, 0.01%

# %%
DATA_CLEANED["code"] = DATA["code"].apply(clean_code, verbose=1)

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["code"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 23, 0.01%
# Number of value removed = 0, 0.00%

# %% [markdown]
# Aucun code produit ne semble aberrant

# %% [markdown]
# ### Nettoyage des url
# L'url doit avoir le bon format
# L'url doit être accessible (en option)
# L'url doit correspondre au bon code produit

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["url"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 23, 0.01%

# %% [markdown]
# NB : utiliser verify_exists=False pour un test rapide
# La vérification que l'url existe est (très) long,
# la vérification a été réalisée sur un autre pc.
# Le résultat est rechargé ensuite.
# Une fonction de parallélisation a été créer pour gagner du temps.
# Temps nécessaire : ~10h sur 4 procs

# %% [markdown]
# #### nettoyage rapide (sans vérifier que l'url existe)

# %%
DATA_CLEANED["url"] = clean_url(DATA["url"], DATA_CLEANED["code"], verify_exists=False, verbose=1) #fast checking

# %% [markdown]
# #### chargement du dataframe nettoyé avec vérification que l'url existe

# %%
df_url_file = "database_cleaned_url_para.csv"
if os.path.isfile(df_url_file) :
    DF_URL = pd.read_csv(df_url_file, sep=";", low_memory=False)
else :
    DF_URL = pd.DataFrame(columns=selected_columns)
if len(DF_URL) != len(DATA_CLEANED) :
    print("Error in the dataframe loaded")
else :
    DATA_CLEANED['url'] = DF_URL['url']

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["url"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 2375, 0.74%
# Number of value removed = 2352, 0.73%

# %% [markdown]
# Il apparait que des url ne sont pas accessible, il est donc inutile de garder un lien vers une page erronnée.
# Cependant ce nombre est faible et ne représente que 0.73% de la base de données

# %% [markdown]
# ### Nettoyage des noms des produits
# Le nom des produits doit être de type str
# Le nom des produits doit contenir au moins 4 caractères
# Traduire les noms des produits en minuscules
# Remplacer les espaces par des "_" pour faciliter le parcours des noms

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["product_name"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 17762, 5.54%

# %%
DATA_CLEANED["product_name"] = DATA["product_name"].apply(is_str, min_size=3)
# Out:
#   is not correct value => ignored
# Fe is not correct value => ignored
# 짜왕 is not correct value => ignored
# M is not correct value => ignored
# H is not correct value => ignored
# 통깨 is not correct value => ignored
# 旺仔 is not correct value => ignored
# O is not correct value => ignored
# ok is not correct value => ignored
# 你 is not correct value => ignored
# a is not correct value => ignored
# W5 is not correct value => ignored
# 알 is not correct value => ignored
# bn is not correct value => ignored
# K is not correct value => ignored
# 3d is not correct value => ignored
# P is not correct value => ignored
# O is not correct value => ignored
# Hf is not correct value => ignored
# LF is not correct value => ignored
# 昆布 is not correct value => ignored
# 曾粉 is not correct value => ignored
# Tf is not correct value => ignored
# 煎茶 is not correct value => ignored
# 緑茶 is not correct value => ignored
# ゆず is not correct value => ignored
# 月餅 is not correct value => ignored
# Bn is not correct value => ignored
# BN is not correct value => ignored
# A is not correct value => ignored
# C is not correct value => ignored
# DL is not correct value => ignored
# u is not correct value => ignored
# 9° is not correct value => ignored
# 6 is not correct value => ignored
# bb is not correct value => ignored
# vh is not correct value => ignored
# vh is not correct value => ignored
# 24 is not correct value => ignored
# 1 is not correct value => ignored
# 飞鹤 is not correct value => ignored
# 麻花 is not correct value => ignored
# 面包 is not correct value => ignored
# As is not correct value => ignored
#   is not correct value => ignored
# U is not correct value => ignored
# U is not correct value => ignored
# ff is not correct value => ignored
# Mu is not correct value => ignored
# TO is not correct value => ignored
#   is not correct value => ignored
# 86 is not correct value => ignored
# rr is not correct value => ignored
# 🍺 is not correct value => ignored
# 미역 is not correct value => ignored
# 쌀떡 is not correct value => ignored
# V is not correct value => ignored

# %%
DATA_CLEANED["product_name"] = DATA_CLEANED["product_name"].apply(str_replace, args=(" ", "_")).apply(lower_case)

# %%
print_random(DATA_CLEANED['product_name'], 10)
# Out:
# 21044                     brigham's,_ice_cream,_vanilla
# 148290           fiorello's,_artisan_gelato,_strawberry
# 64378                                      lemon_pepper
# 241990    tournesol_allégée_50%_mg_(tartines_&_cuisson)
# 163870               lemon_pepper_artisan_chicken_jerky
# 116151          organic_instant_oatmeal,_apple_cinnamon
# 311639                          turrón_de_coco_al_cacao
# 254067                                polenta_savoyarde
# 124899                nature's_promise,_organic_walnuts
# 11914                rice_&_pasta_mix,_cheddar_broccoli
# Name: product_name, dtype: object

# %% [markdown]
# Les noms des produits peuvent commencer ou finir par un espace:
# A supprimer

# %%
DATA_CLEANED["product_name"] = DATA_CLEANED['product_name'].apply(remove_underscore_start_end)

# %%
print_random(DATA_CLEANED['product_name'], 10)
# Out:
# 196504                       maxi_croquantes_nature
# 164374                    sausage_egg_cheese_slider
# 66665     hobnobs_rolled_oat_&_whole_wheat_biscuits
# 83871        marcelled_potato_chips,_salt_&_vinegar
# 95760                             black_bean_&_corn
# 36632                 all_natural_dried_cranberries
# 163035             blueberry_merlot_chandoka_spread
# 153542               jumbo_cashews_sea_salt_roasted
# 225609                                  à_l'olivier
# 180214                         bifidus_ananas_(4_x)
# Name: product_name, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["product_name"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 17819, 5.56%
# Number of value removed = 57, 0.02%

# %% [markdown]
# 57 noms de produits ont été considérés aberrantes, soit 0.02%

# %% [markdown]
# ### nettoyage des catégories
# Creation de l'objet list pour faciliter le parcours
# traduction des tag en anglais
# attention la traduction est longue
# Problème : Google accepte un nombre limité de requète par seconde, heure, jour...
# Donc changement de stratégie : créer un dict avec les champs à traduire et effecter la traduction en une seule requète

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["categories_tags"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 236383, 73.69%

# %%
DATA_CLEANED["categories_tags"] = DATA["categories_tags"].apply(create_list)

# %%
print_random(DATA_CLEANED[DATA_CLEANED['categories_tags'].str.len() != 0]['categories_tags'], 10)
# Out:
# 253935    [en:beverages, en:alcoholic-beverages, en:beer...
# 202114    [en:beverages, en:hot-beverages, en:coffees, e...
# 208425    [en:plant-based-foods-and-beverages, en:plant-...
# 178600           [en:meats, en:beef, fr:entrecote-de-boeuf]
# 203741    [en:fresh-foods, en:dairies, en:desserts, en:d...
# 246272    [en:meats, en:prepared-meats, fr:charcuteries-...
# 307179    [en:sugary-snacks, en:biscuits-and-cakes, en:b...
# 93599     [en:plant-based-foods-and-beverages, en:plant-...
# 264452           [en:dairies, en:cheeses, en:cream-cheeses]
# 232277    [en:sugary-snacks, en:biscuits-and-cakes, en:b...
# Name: categories_tags, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 236383, 73.69%
# Number of value removed = 0, 0.00%

# %% [markdown]
# #### Chargement du dictionnaire
# Puisque la traduction est longue, un dictionnaire est sauvegardé pour éviter de relancer à chaque fois

# %%
to_translate_file = "dict_to-translate.pkl"
translated_file = "dict_translated.pkl"
if os.path.isfile(to_translate_file) and \
os.path.isfile(translated_file):
    with open(to_translate_file, 'rb') as file :
        to_translate = pickle.load(file)
    with open(translated_file, 'rb') as file :
        translated = pickle.load(file)
else :
    print("No dict saved")
    to_translate = {}
    translated = {}

# %% [markdown]
# #### recherche des valeurs à traduire

# %%
to_translate = create_translate_dict(DATA_CLEANED["categories_tags"].values, old=to_translate)
# Out:
# Unknown language ['xx', 'attiksgurka']
# Unknown language ['xx', 'liszt']
# Unknown language ['xx', 'вафли']
# Unknown language ['xx', 'вафли']
# Unknown language ['xx', 'кисело-мляко']
# Unknown language ['xx', 'barre-chocolatee']
# Unknown language ['xx', 'fiskekonserves']
# Unknown language ['xx', 'helkonserves']
# Unknown language ['xx', 'кисело-мляко']
# Unknown language ['xx', '煎茶']
# Unknown language ['xx', 'スナック菓子']
# Unknown language ['xx', 'ポップコーン']
# Unknown language ['xx', 'paste']
# Unknown language ['xx', 'paste-făinoase']
# Unknown language ['xx', 'grøntsag']
# Unknown language ['xx', 'confiseries']
# Unknown language ['xx', 'snacks-sucres']
# Unknown language ['xx', 'brød']
# Unknown language ['xx', 'brød']
# Unknown language ['xx', 'fiskepalaeg']
# Unknown language ['xx', 'kosttilskud']
# Unknown language ['xx', 'remoulade']
# Unknown language ['xx', 'orange-juice-from-concentrate']
# Unknown language ['xx', 'krydderi']
# Unknown language ['xx', 'bouillonterning']
# Unknown language ['xx', 'krydderi']
# Unknown language ['xx', 'salmiak']
# Unknown language ['xx', 'vin']
# Unknown language ['xx', 'jul']
# Unknown language ['xx', 'vegansk']
# Unknown language ['xx', 'chokolade-bar']
# Unknown language ['xx', 'вафли']
# Unknown language ['xx', 'snack']
# Unknown language ['xx', 'epicerie']
# Unknown language ['xx', 'sauces-tomate']
# Unknown language ['xx', 'banh']

# %% [markdown]
# #### traduction

# %%
translated = translate_dict(to_translate, old=translated)
#print(translated)
# Out:
# Translation of fr in progress
# Done
# Translation of de in progress
# Done
# Translation of it in progress
# Done
# Translation of es in progress
# Done
# Translation of auto in progress
# Done
# Translation of pt in progress
# Done
# Translation of ge in progress
# Failed to translate ge
# Done
# Translation of nl in progress
# Done
# Translation of ru in progress
# Done
# Translation of ar in progress
# Done
# Translation of ja in progress
# Done
# Translation of ko in progress
# Done
# Translation of tr in progress
# Done
# Translation of la in progress
# Done
# Translation of ro in progress
# Done
# Translation of el in progress
# Done
# Translation of pl in progress
# Done
# Translation of cs in progress
# Done
# Translation of zh in progress
# Failed to translate zh
# Done
# Translation of fi in progress
# Done
# Translation of sv in progress
# Done
# Translation of da in progress
# Done
# Translation of hu in progress
# Done
# Translation of he in progress
# Failed to translate he
# Done
# Translation of sk in progress
# Done
# Translation of th in progress
# Done
# Translation of vi in progress
# Done

# %% [markdown]
# ##### Sauvegarde du dictionnaire traduit pour éviter de le recréer

# %%
with open("dict_to-translate.pkl", 'wb') as ofile :
    pickle.dump(to_translate, ofile)
with open("dict_translated.pkl", "wb") as ofile :
    pickle.dump(translated, ofile)

# %% [markdown]
# #### Application des traductions

# %%
DATA_CLEANED["categories_tags"] = DATA_CLEANED["categories_tags"].apply(apply_translation, args=(to_translate, translated))
# Out:
# Value of text is strange : u => ignored
# Failed to translate kakheti with original language ge
# Failed to translate sauce-de-soja with original language zh
# Value of text is strange : p => ignored
# Failed to translate tofu-seche with original language zh
# Value of text is strange : 茶 => ignored
# Value of text is strange : 0 => ignored
# Value of text is strange :  => ignored
# Value of text is strange :  => ignored
# Failed to translate 啤酒 with original language zh
# Failed to translate chinese-wines with original language zh
# Failed to translate 复原乳 with original language zh
# Failed to translate משקאות-קלים with original language he
# Failed to translate aliments-d-origine-vegetale with original language he
# Failed to translate aliments-et-boissons-a-base-de-vegetaux with original language he
# Failed to translate cereales-et-derives with original language he
# Failed to translate cereales-et-pommes-de-terre with original language he
# Failed to translate cereales-pour-petit-dejeuner with original language he
# Failed to translate לחם with original language he

# %% [markdown]
# #### affichage du résultat

# %%
print_random(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() != 0 ]['categories_tags'], 10)
# Out:
# 226986                       [pie-dough, shortcrust pastry]
# 195265    [plant-based-foods-and-beverages, plant-based-...
# 226935                       [pie-dough, shortcrust pastry]
# 300554    [plant-based-foods-and-beverages, plant-based-...
# 279659          [groceries, sauces, tomato-sauces, ketchup]
# 204383    [beverages, alcoholic-beverages, wines, french...
# 252078    [plant-based-foods-and-beverages, plant-based-...
# 215406    [plant-based-foods-and-beverages, plant-based-...
# 265803    [farming-products, bird-eggs, eggs, free-range...
# 212344    [canned-foods, seafood, fishes, canned-fishes,...
# Name: categories_tags, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 236388, 73.69%
# Number of value removed = 5, 0.00%

# %% [markdown]
# il y a pas une uniformité dans les espaces
# parfois " ", parfois '-'
# choix de mettre que des '-'
# Vérifier qu'un tag ne se retrouve pas deux fois dans la même liste

# %%
DATA_CLEANED["categories_tags"] = DATA_CLEANED["categories_tags"].apply(list_replace, args=(" ", "-"))

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 236388, 73.69%
# Number of value removed = 5, 0.00%

# %%
DATA_CLEANED["categories_tags"] = DATA_CLEANED["categories_tags"].apply(set).apply(list)

# %%
print_random(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() != 0]["categories_tags"], 10)
# Out:
# 111684    [farming-products, sweeteners, breakfasts, hon...
# 311885                        [croque-monsieur, sandwiches]
# 271446    [carbonated-drinks, carbonated-waters, non-sug...
# 265864                        [hams, prepared-meats, meats]
# 253536    [sugary-snacks, biscuits-and-cakes, Breton-pan...
# 235835    [artificially-sweetened-beverages, iced-teas, ...
# 219348    [frozen-foods, meals, frozen-ready-made-meals,...
# 248166    [fruits-and-vegetables-based-foods, plant-base...
# 204134    [block-of-foie-gras, block-of-foie-gras-with-p...
# 278109    [fruits-and-vegetables-based-foods, meals, ref...
# Name: categories_tags, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["categories_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 236388, 73.69%
# Number of value removed = 5, 0.00%

# %% [markdown]
# Uniquement 5 lignes n'ont plus de catégories, cela signifie que lorsque des valeurs aberrantes ont été supprimées,
# il existait une autre catégorie pour ce produit.

# %% [markdown]
# ### Nettoyage des lieux de productions et transformations
# Les lieux de productions doivent être du type str
# Pour faciliter, les valeurs doivent contenir le nom d'un pays
# Sinon elles sont considérées comme aberrantes puisqu'elles ne peuvent pas être traitées automatiquement
# Le résultats sont stockés dans des listes
#
# Remplacer les virgules par des " " pour identifier facilement les mots
# Recherche d'un nom de pays parmis les mots
# Il faut supprimer les accents et la majuscule pour ne pas fausser la comparaison

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["manufacturing_places_tags"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 284277, 88.62%

# %%
DATA_CLEANED["manufacturing_places_tags"] = DATA['manufacturing_places_tags'].apply(is_str)
DATA_CLEANED["manufacturing_places_tags"] = DATA_CLEANED['manufacturing_places_tags'].apply(str_replace, args=(",", " "))
DATA_CLEANED["manufacturing_places_tags"] = DATA_CLEANED["manufacturing_places_tags"].apply(lower_case)
DATA_CLEANED["manufacturing_places_tags"] = DATA_CLEANED["manufacturing_places_tags"].apply(remove_accent)
DATA_CLEANED["manufacturing_places_tags"] = DATA_CLEANED["manufacturing_places_tags"].apply(find_country, args=(COUNTRIES,))
DATA_CLEANED["manufacturing_places_tags"] = DATA_CLEANED["manufacturing_places_tags"].apply(create_list)
# Out:
# No country detected in brossard quebec
# No country detected in brossard quebec
# No country detected in brossard quebec
# No country detected in brossard quebec
# No country detected in brossard quebec
# No country detected in brossard quebec
# No country detected in topco
# No country detected in norwalk ct
# No country detected in u s a
# No country detected in californie
# No country detected in u s a
# No country detected in united states if america
# No country detected in etats unis d amerique
# No country detected in marlborough massachusetts
# No country detected in u s a
# No country detected in us california
# No country detected in quetigny
# No country detected in tyskland
# No country detected in blainville quebec
# No country detected in dieppe n b
# No country detected in more than one country
# No country detected in st donat quebec
# No country detected in boisbriand quebec
# No country detected in ancaster ontario
# No country detected in montreal quebec
# No country detected in levis quebec
# No country detected in dy hyacinthe quebec
# No country detected in saint antoine de tilly quebec
# No country detected in brampton ontario
# No country detected in st hyacinthe quebec
# No country detected in saint augustin de desmaures quebec
# No country detected in longeuil qc markham on victoria bc
# No country detected in st hubert quebec
# No country detected in quebec
# No country detected in ontario
# No country detected in mississauga on quebec qc
# No country detected in mississauga on quebec qc
# No country detected in saint leonard quebec
# No country detected in toronto ontario
# No country detected in don mills ontario
# No country detected in adstock quebec
# No country detected in angliia
# No country detected in eu
# No country detected in stockton ca
# No country detected in vacaville ca
# No country detected in min e u a
# No country detected in cincinnati oh
# No country detected in corona ca
# No country detected in winston salem north carolina
# No country detected in isvicre
# No country detected in charlotte nc
# No country detected in Zhong Guo Zhi Zao
# No country detected in grande bretagne
# No country detected in great britain
# No country detected in tahiti
# No country detected in londonderry new hampshire
# No country detected in ottawa ontario
# No country detected in e u a
# No country detected in ottawa on
# No country detected in ottawa ontario
# No country detected in e u a
# No country detected in st louis missouri
# No country detected in auvergne
# No country detected in poligny jura bourgogne franche comte
# No country detected in levis quebec
# No country detected in tahiti
# No country detected in saint flour
# No country detected in fermiers du gers 32100 condom
# No country detected in great britain
# No country detected in gard
# No country detected in montreal quebec
# No country detected in missisauga ontario
# No country detected in ssha
# No country detected in saint louis 974
# No country detected in markham on
# No country detected in u s a
# No country detected in londres
# No country detected in la baie
# No country detected in toronto ontario
# No country detected in sainte cecile de milton quebec
# No country detected in longueuil quebec
# No country detected in ssha
# No country detected in scottsdale arizona
# No country detected in plovdiv
# No country detected in ontario cda
# No country detected in notre dame de lourdes quebec
# No country detected in montreal quebec
# No country detected in Ri Ben
# No country detected in montreal quebec
# No country detected in manitoba cdn
# No country detected in watsonville ca
# No country detected in quebec
# No country detected in fort bragg california
# No country detected in mississauga ontario
# No country detected in cuisine par fleury michon
# No country detected in quebec saint jean baptiste
# No country detected in boisbriand quebec
# No country detected in city of industry ca
# No country detected in carib brewery limited champs fleurs trinidad
# No country detected in grande bretagne
# No country detected in chicago il
# No country detected in listowel ontario
# No country detected in st theodore d acton quebec
# No country detected in montreal quebec
# No country detected in us
# No country detected in philipines
# No country detected in mountain view ca
# No country detected in berkeley ca
# No country detected in crowny food industries bv zaandam nederland
# No country detected in vancouver bc
# No country detected in vancouver
# No country detected in rossiia
# No country detected in lima
# No country detected in northumberland pennsylvania
# No country detected in sonoma california
# No country detected in mas vezian 66350 toulouges
# No country detected in saint paul en jarez
# No country detected in lithuanie
# No country detected in californie
# No country detected in agen
# No country detected in pos sidorovka g naberezhnye chelny resublika tatarstan rossiia
# No country detected in de katjang bv koekoeksedijk 14 4761 pj zevenbergen nederland
# No country detected in v'etnam
# No country detected in posiolok novyi svet gatchinskii raion leningradskaia oblast' rossiia
# No country detected in normandie
# No country detected in arpajon
# No country detected in deville les rouen val de saone saint martin de londres
# No country detected in queyssac dordogne
# No country detected in alsace
# No country detected in great britain
# No country detected in great britain
# No country detected in lidl
# No country detected in bamako
# No country detected in murcia
# No country detected in casa taradellas barcelona
# No country detected in 03530 la nucia
# No country detected in florette food service 66440 torreilles
# No country detected in lozere
# No country detected in bockum hovel
# No country detected in grande bretagne
# No country detected in ardeche
# No country detected in e a sas annecy 74000
# No country detected in bialystok
# No country detected in le mans
# No country detected in ruoms
# No country detected in moosehead breweries ltd saint john new brunswick
# No country detected in dakar
# No country detected in cave de saint cyr en bourg
# No country detected in andalousie
# No country detected in brooklyn ny 11211
# No country detected in plouvien
# No country detected in turkiye
# No country detected in ankara turkiye
# No country detected in saint gregoire
# No country detected in 68350 brunstatt
# No country detected in 35230 bourgbarre
# No country detected in gorod izhevsk udmurtskaia respublika rossiia
# No country detected in mesnay
# No country detected in 3 chemin de la sandlach 67501 haguenau cedex
# No country detected in mesnay
# No country detected in franca
# No country detected in roquefort
# No country detected in rossiia chekhov moskovskaia oblast'
# No country detected in rossiia
# No country detected in freiburg
# No country detected in les courgons 04140 provence alpes cote d azur selonnet
# No country detected in http www episaveurs fr produit epicerie produit 0004596 html
# No country detected in 42008 st etienne
# No country detected in camembert
# No country detected in normandie
# No country detected in berlin
# No country detected in rsfsr sssr rossiia
# No country detected in indre et loire 37160
# No country detected in asturias
# No country detected in moskva sssr rsfsr
# No country detected in inconnue
# No country detected in berlin
# No country detected in eskisehir turkiye
# No country detected in karaman turkiye
# No country detected in dudullu istanbul turkiye
# No country detected in turkiye
# No country detected in umraniye
# No country detected in idaho falls u s a
# No country detected in 75009 paris
# No country detected in jandu strasbourg
# No country detected in lyon
# No country detected in corbas
# No country detected in saint jean de monts
# No country detected in privatmolkerei bechtel molkereistrasse 5 d 92521 schwarzenfeld
# No country detected in alemanha
# No country detected in cote du rhone
# No country detected in espanha
# No country detected in strasbourg
# No country detected in lactalis nestle ultra frais mdd filiale groupe lactalis za les placis 35230 bourgarre fr 47 185 001 ce
# No country detected in lidl stiftung co neckarsulm
# No country detected in saint pierre du mont landes
# No country detected in wiefelstede dringenburg
# No country detected in s starosel'e brianskii raion brianskaia oblast' rossiia
# No country detected in d starosel'e brianskii r n brianskaia obl rf 241525
# No country detected in p molkombinata g rudnia rossiiskaia federatsiia smolenskaia oblast'
# No country detected in poselok krasnolit g krasnodar rossiia
# No country detected in s kumovskoe babyninskii raion kaluzhskaia oblast' rossiiskaia federatsiia
# No country detected in grande bretagne
# No country detected in limoges
# No country detected in de ev 3 eg
# No country detected in murcia lote aa13
# No country detected in 67723 hoerdt alsace lait
# No country detected in gorod naberezhnye chelny respublika tatarstan rossiia
# No country detected in fao 67 fao 61
# No country detected in duitsland
# No country detected in espanha
# No country detected in montelimar
# No country detected in inconnu
# No country detected in schwarzenfeld alemanha
# No country detected in 25690 avoudrey
# No country detected in strasbourg
# No country detected in 72400 la ferte bernard
# No country detected in noel alimentaria s a u girona
# No country detected in alemanha
# No country detected in bissingen molkerei gropper gmbh co kg am muhberg 2 d 86657 bissingen
# No country detected in za les placis 35230 bourgbarre
# No country detected in espanha
# No country detected in huber gmbh co karwendelstrasse 6 16 d 86802 buchloe
# No country detected in ivory coast
# No country detected in f 38490 les abrets
# No country detected in kervignac
# No country detected in 39800 poligny
# No country detected in cz
# No country detected in inconnu
# No country detected in arroyo de la encomienda valladolid
# No country detected in placensia caceres
# No country detected in montbazin
# No country detected in d 92521 schwarzenfeld
# No country detected in alemanha
# No country detected in bayern
# No country detected in senagral 30 rue des jacquins 89150 jouy
# No country detected in bretagne
# No country detected in sill le raden bp1 29860 plouvien
# No country detected in lisieux
# No country detected in transportnyi proezd g odintsovo mo 143000 rossiia
# No country detected in ellada
# No country detected in albal valencia
# No country detected in lamayou 64460
# No country detected in fromagerie de clerval f 25340 santoche
# No country detected in 89771 chailley
# No country detected in fromageries occitanes 15220 saint mamet
# No country detected in pontevedra espanha
# No country detected in uniao europeia
# No country detected in paises baixos
# No country detected in sprundel holland
# No country detected in elsa estavayer lait s a ch 1470 estavayer le lac
# No country detected in hollande
# No country detected in emb 14752b
# No country detected in uglich
# No country detected in leppersdorf alemanha
# No country detected in gronau alemanha
# No country detected in valencia
# No country detected in valencia
# No country detected in holanda
# No country detected in robert bosch str 13 85053 ingolstadt
# No country detected in alicante
# No country detected in bunol valencia
# No country detected in bunol
# No country detected in azuqueca de henares guadalajara espanha
# No country detected in irun guipuzcoa espanha
# No country detected in ibi alicante espanha
# No country detected in alemanha
# No country detected in la mirande 66240 saint esteve
# No country detected in wachau
# No country detected in holland
# No country detected in ul iuzhnaia sheremet'evskii mkr g dolgoprudnyi moskovskaia oblast' rossiia 141720
# No country detected in alemanha
# No country detected in 69400 limas
# No country detected in lille
# No country detected in 47110
# No country detected in jacques ijs nv nijverheidsstraat 54 b 2260 westerlo
# No country detected in phillipines
# No country detected in cote d ivoire
# No country detected in delpierre mer et tradition 62360 hesdin l abbe
# No country detected in hesdin l abbe
# No country detected in la celle sous gouzon 23230
# No country detected in xirivella valencia
# No country detected in 56700 kervignac
# No country detected in e u
# No country detected in 47500 montayral
# No country detected in delpierre mer et tradition 62360 hesdin l abbe
# No country detected in hollande
# No country detected in grande bretagne
# No country detected in 52 rue jean pierre timbaut 95192 goussainville
# No country detected in 66968 perpignan
# No country detected in andrezieux boutheon
# No country detected in saint christol les ales
# No country detected in maitres laitiers du cotentin sottevast
# No country detected in haute savoie
# No country detected in cotentin
# No country detected in alsace 67728 hoerdt
# No country detected in cooperative laitiere 12600 therondels
# No country detected in menissez sas 59750 feignies
# No country detected in alicnte
# No country detected in envasado por productos florida almazora castellon
# No country detected in almazora castellon
# No country detected in australi
# No country detected in frankrijk
# No country detected in recogne
# No country detected in cite marine ci du porzo 56700 kervignac
# No country detected in fr 74 225 052 ce
# No country detected in moskovskaia oblast' rossiia
# No country detected in cestas
# No country detected in mazedonien
# No country detected in rgsa 10 05771 m
# No country detected in soria
# No country detected in enasado en atmosfera modificada indudtria carnicas meca madrid
# No country detected in barcelona lote 756 3 14
# No country detected in madrid
# No country detected in madrid
# No country detected in madrid
# No country detected in girona
# No country detected in murcia
# No country detected in murcia
# No country detected in saratov rossiia
# No country detected in althen des paluds
# No country detected in eu
# No country detected in bretagne
# No country detected in aisne
# No country detected in fr 59 165 030 ce
# No country detected in fabrique pour lnuf marques 2 rue du centre 93160 noisy le grand
# No country detected in noisy le grand 93
# No country detected in noisy le grand
# No country detected in champagne sarthe
# No country detected in strasbourg
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in nord
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in 0
# No country detected in non indique
# No country detected in hepreville
# No country detected in fecamp
# No country detected in fecamp
# No country detected in wisches
# No country detected in frince
# No country detected in marseille
# No country detected in gms meunerie strasbourg
# No country detected in volvic
# No country detected in sud ouest
# No country detected in marseille
# No country detected in marseille
# No country detected in source saint galmier
# No country detected in frankfreich
# No country detected in badoit bron 42330 saint galmier
# No country detected in normandie
# No country detected in 29360 clohars carnoet
# No country detected in moroco
# No country detected in strasbourg
# No country detected in nimes
# No country detected in u e
# No country detected in le woestyne 59173 renescure
# No country detected in villeneuve d ascq
# No country detected in bell la woestyne 59173 renescure
# No country detected in villeneuve d ascq
# No country detected in 64290 gan
# No country detected in pyrenees
# No country detected in 64290 gan
# No country detected in pyrenees
# No country detected in communaute europeenne
# No country detected in communaute europeenne
# No country detected in communaute europeenne
# No country detected in b nord e saone loire
# No country detected in 01 ain
# No country detected in aix en provence
# No country detected in gemenos
# No country detected in bretagne
# No country detected in bretagne
# No country detected in frantsiia
# No country detected in gossetlaan 54 1702 groot bijgaarden belgie
# No country detected in fougerolles
# No country detected in 33290 blanquefort feance
# No country detected in cote d ivoire
# No country detected in madere
# No country detected in grande bretagne
# No country detected in europe
# No country detected in frabkreich
# No country detected in gouvieux
# No country detected in gouvieux
# No country detected in cote d ivoire
# No country detected in 128 boulevard jules vernes 44300 nantes
# No country detected in nutrition et sante sas 31250 revel
# No country detected in revel haute garonne
# No country detected in nutrition et sante sas 31250 revel
# No country detected in 31250 revelfrance
# No country detected in normandie
# No country detected in 2 bvd de l industrie
# No country detected in sarthe
# No country detected in domaine de sahari
# No country detected in 63 clermont ferrand
# No country detected in uclab industrie union des cooperatives laitieres bretonnes filiale laita zi de lanrinou 29800 pencran finistere bretagne
# No country detected in 67930 beinheim
# No country detected in rosporden
# No country detected in alsace
# No country detected in 48500 le massegros
# No country detected in savoie
# No country detected in laiterie des ardennes solarec
# No country detected in emb 56094c
# No country detected in alsace
# No country detected in normandie
# No country detected in lonlay l abbaye
# No country detected in normandie
# No country detected in farine de bl fabrication 100 francaise
# No country detected in inconnue
# No country detected in vendee
# No country detected in eyguebelle vallaurie
# No country detected in eyguebelle vallaurie
# No country detected in eyguebelle vallaurie
# No country detected in eyguebelle vallaurie
# No country detected in eyguebelle vallaurie
# No country detected in conserverie du languedoc castelnaudary
# No country detected in 63460 teilhede
# No country detected in franche comte
# No country detected in 13400 aubagne
# No country detected in isigny
# No country detected in bigard 29300 quimperle
# No country detected in maine loire lettres st vendee lettres as
# No country detected in bretagne
# No country detected in coroos conserven b v middenweg 1 4421 jg kapelle pays bas pour cmi tsa 91431 91343 massy cedex
# No country detected in les vins du littoral saint felix de lodez fr
# No country detected in alsace
# No country detected in fournil du val de loire
# No country detected in haute savoie
# No country detected in domessin
# No country detected in saint maurice de lignon
# No country detected in non indique
# No country detected in puteaux
# No country detected in capitaine cook s a s za de keranna 29360 clohars carnoet
# No country detected in 31016 toulouse yeo frais 183 avenue des etats unis
# No country detected in 45300 pithivier
# No country detected in joue les tours
# No country detected in 45110 saint martin d abbat
# No country detected in marges
# No country detected in antartic saint martin d abbat val de loire
# No country detected in clohars carnoet
# No country detected in correze
# No country detected in pyrenees atlantiques
# No country detected in italcanditi
# No country detected in emg de ste marguritte 63270 st maurice es allier
# No country detected in reims
# No country detected in capitaine cook s a s za de keranna 29360 clohars carnoet
# No country detected in covi sas 79300 bressuire
# No country detected in delvert
# No country detected in bretagne
# No country detected in bretagne
# No country detected in casseneuil
# No country detected in les delices de saint leonard theix bretagne
# No country detected in s a s s c o b p 20022 29563 quimper cedex 9
# No country detected in s a s s c o b p 20022 29563 quimper cedex 9
# No country detected in maromme
# No country detected in racio s r o narodnich hrdinu 3146 22b 690 02 breclav moravie du sud republique tcheque
# No country detected in breclav republic tcheque
# No country detected in fr 44 072 002 ce emb 44072
# No country detected in cooperative d isigny sainte mere
# No country detected in sottevast
# No country detected in capitaine cook s a s za de keranna 29360 clohars carnoet
# No country detected in emb 61486a
# No country detected in antartic 45110 saint martin d abbat
# No country detected in republique tcheque racio sro naradnich hrdinu 69002 breclav
# No country detected in la celle sous gouzon creuse
# No country detected in 33650
# No country detected in saviel janze
# No country detected in cote d ivoire
# No country detected in lons
# No country detected in delvert
# No country detected in marie de livinac 12300 decazeville
# No country detected in tilburg nederland
# No country detected in biokorn gmbh
# No country detected in allemag e
# No country detected in lactunion
# No country detected in lsdh 45550 saint denis de l hotel
# No country detected in ggf 80700 roye
# No country detected in ggf moreuil
# No country detected in nv snack food poco loco rumbeeksegravier 157 8800 roeselaere belgie
# No country detected in alsace
# No country detected in saint pere en retz
# No country detected in saint martin d abbat
# No country detected in bourgogne
# No country detected in revel 31250
# No country detected in u e
# No country detected in quimper
# No country detected in bretagne quimper finistere
# No country detected in bretagne
# No country detected in fance normandie
# No country detected in livarot normandie
# No country detected in chambery cedex
# No country detected in f 69730 genay
# No country detected in cooperative isigny sainte mere
# No country detected in u e
# No country detected in u e
# No country detected in bretagne
# No country detected in inconnu
# No country detected in st flour cantal
# No country detected in voir emballage
# No country detected in isere
# No country detected in charrancieu 38
# No country detected in les sources de soultzmatt 68570 soultzmatt
# No country detected in st christol lez ales
# No country detected in fr 86 160 002 ce 86160a
# No country detected in chaspuzac haute loire auvergne
# No country detected in cote d ivoire
# No country detected in fr 24 328 002 ce
# No country detected in luchon
# No country detected in provence carqueiranne
# No country detected in midi pyrenees
# No country detected in soy nutrition et nature zi de la pomme 31250 revel
# No country detected in haute provence
# No country detected in bretagne
# No country detected in saint tugdual
# No country detected in bretagne
# No country detected in cooperative du nyonsais
# No country detected in californie
# No country detected in cote d ivoire
# No country detected in cote d ivoire
# No country detected in bretagne
# No country detected in preparees en bretagne
# No country detected in douarnenez
# No country detected in bretagne finistere
# No country detected in cote d ivoire
# No country detected in ile maurice
# No country detected in u e
# No country detected in castelnaudary
# No country detected in cemoi chocolatier etablissement de tinchebray 61
# No country detected in alysse food sa zone industrielle c rue charles richet 7180 seneffe blgique
# No country detected in pays bas helwa wafelbakkerij bv 9074 ag hallum
# No country detected in hofbrauhaus vertriebs gmbh karlsbergerstrasze 62 66424 homburg
# No country detected in emb 26174b
# No country detected in ile de groix
# No country detected in pays basque
# No country detected in sa perrin vermot 25330 cleron franche comte
# No country detected in danmark
# No country detected in fromagerie d auxon auxon 10130
# No country detected in dannemark
# No country detected in societe laitiere de l hermitage filiale groupe lactalis place de la gare 35590 l hermitage ille et vilaine bretagne
# No country detected in fr 72 264 002 ce
# No country detected in bourges
# No country detected in normandie
# No country detected in franois
# No country detected in 22330 saint jacut du mene
# No country detected in romans
# No country detected in volaille 100 francaise
# No country detected in st hilaire de briouze
# No country detected in saint hilaire de briouze normandie
# No country detected in ardeche vals les bains
# No country detected in ribeauville
# No country detected in confit de provence
# No country detected in ile maurice
# No country detected in smda le genestoux 63240 le mont dore
# No country detected in provence
# No country detected in franche comte
# No country detected in benifontaine pas de calais
# No country detected in perigueux
# No country detected in bretagne
# No country detected in bretagne
# No country detected in aix en provence
# No country detected in d160 34600 les aires
# No country detected in grande bretagne
# No country detected in grande bretagne
# No country detected in mayenne
# No country detected in alsace 67580 mietesheim
# No country detected in 29510 landrevarzec
# No country detected in savoie
# No country detected in europe
# No country detected in st malo
# No country detected in gironde
# No country detected in saint pierre 974
# No country detected in gertwiller alsace
# No country detected in brioches fonteneau 11 rue du calvaire 85260 la copechagniere
# No country detected in gironde
# No country detected in pierreclos
# No country detected in pays basque
# No country detected in eggteam domaine de l orme 45510 neuvy en sullias loiret centre
# No country detected in eggteam domaine de l orme 45510 neuvy en sullias loiret centre
# No country detected in charente maritime
# No country detected in abbaye de la coudre soeurs cisterciennes de laval
# No country detected in normandie bayeux
# No country detected in poitou
# No country detected in la possession 974
# No country detected in vitamont 47150 monflanquin
# No country detected in saint louis 974
# No country detected in ch 224
# No country detected in marseille
# No country detected in fromagerie delin
# No country detected in non indique
# No country detected in 47300 bias
# No country detected in languedoc roussilon
# No country detected in vertou
# No country detected in vertou
# No country detected in vendee
# No country detected in vendee
# No country detected in mouilleron en pareds vendee
# No country detected in mont ventoux
# No country detected in provence
# No country detected in fabrique a plouedern bretagne
# No country detected in provence
# No country detected in normandie
# No country detected in montsecret
# No country detected in pontivy
# No country detected in mornant
# No country detected in mornant
# No country detected in vitenam
# No country detected in bordeaxu
# No country detected in sud ouest virazeil 47200
# No country detected in normandie
# No country detected in 31220 martres tolosane
# No country detected in val de loire
# No country detected in pyrenees
# No country detected in bretagne cotes d armor
# No country detected in corse
# No country detected in corse
# No country detected in picardie
# No country detected in thierache
# No country detected in plescop morbihan
# No country detected in alsace
# No country detected in moulin meckert diemer krautwiller
# No country detected in rungis
# No country detected in saint emilion gironde
# No country detected in drome provencale
# No country detected in bretagne
# No country detected in laiterie cooperative de pamplie
# No country detected in europe
# No country detected in europe
# No country detected in moorea
# No country detected in moorea
# No country detected in faverolles fracia
# No country detected in cambremer
# No country detected in bretagne
# No country detected in flavigny
# No country detected in flavigny
# No country detected in vosges
# No country detected in distillerie a blachere route d avignon 84230 chateauneuf du pape
# No country detected in bretagne finistere concarneau
# No country detected in ludres 54710
# No country detected in lorraine
# No country detected in lorraine
# No country detected in herbignac loire atlantique
# No country detected in fr 44 072 002 ce
# No country detected in polignac
# No country detected in coray
# No country detected in stst geours de maremne
# No country detected in romans
# No country detected in lonlay l abbaye
# No country detected in alsace
# No country detected in weyersheim alsace
# No country detected in st medard d eyrans
# No country detected in frontignan
# No country detected in vancia rillieux la pape
# No country detected in 2 via motta di livenza 32600 l isle jourdain
# No country detected in normandie
# No country detected in normandie eure flipou
# No country detected in castelnaudary aude
# No country detected in ile de noirmoutier
# No country detected in ardeche
# No country detected in peaugres
# No country detected in lorraine
# No country detected in scea la ferme du manege 76640 hattenville
# No country detected in biodeal laiterie des monts yssingelais
# No country detected in normandie
# No country detected in 36700 clion
# No country detected in 26600
# No country detected in le croquet de charost sarl amande saveurs z a des 4 routes rn 151 36100 neuvy pailloux
# No country detected in mondelez
# No country detected in jura
# No country detected in sarbazan
# No country detected in sarbazan
# No country detected in sarbazan 40
# No country detected in bretagne
# No country detected in limousin
# No country detected in poitiers
# No country detected in antartic 45110 saint martin d abbat
# No country detected in antartic ii
# No country detected in laos
# No country detected in laos
# No country detected in bretagne ille et vilaine
# No country detected in maine et loire
# No country detected in fabrication francaise
# No country detected in moyon
# No country detected in 50860 moyon
# No country detected in 35 113
# No country detected in za la fontenelle 35113 domagne
# No country detected in terres et cereales za la fontenelle 35113 domagne
# No country detected in gironde
# No country detected in annecy
# No country detected in fromagerie rouzaire tournan en brie
# No country detected in carhaix
# No country detected in corse
# No country detected in corse
# No country detected in corse
# No country detected in corse
# No country detected in ste anne
# No country detected in ste anne renion
# No country detected in moulin d andiran
# No country detected in saint yrieix la perche
# No country detected in bretagne
# No country detected in bretagne
# No country detected in la grande nilliere 49360 maulevrier maulevrier maine et loire 49360 la grande nilliere
# No country detected in roche des ecrins
# No country detected in antilles francaises
# No country detected in la meridienne 36700 le bosc
# No country detected in plouay morbihan bretagne
# No country detected in 46500 gramat
# No country detected in 84600 grillon
# No country detected in 39330 port lesney
# No country detected in wattwiller
# No country detected in pays basque
# No country detected in affine en altitude
# No country detected in yeo frais 183 av des etats unis 31016 toulouse
# No country detected in st victoret
# No country detected in charente
# No country detected in sancoins
# No country detected in beauregard vendon
# No country detected in chateldon
# No country detected in haute provence
# No country detected in 35620 erce en lamee
# No country detected in kaoka
# No country detected in haute savoie
# No country detected in molsheim 67129
# No country detected in vendee
# No country detected in haute provence
# No country detected in revest du bion
# No country detected in 26150
# No country detected in provence
# No country detected in morbihan
# No country detected in earl p tit gone 69670 vaugneray
# No country detected in lussac
# No country detected in tourcoing
# No country detected in sauvaud
# No country detected in bourgogne
# No country detected in beaucaire 30300
# No country detected in portes les valence 26800
# No country detected in brissac
# No country detected in hautes alpes
# No country detected in tahiti
# No country detected in lozere
# No country detected in lozere cevennes
# No country detected in ploubalay 22650
# No country detected in bretagne pleuven
# No country detected in brasserie tonnerre de brest
# No country detected in 18120 brinay
# No country detected in abbaye n d de bonneval
# No country detected in saint etienne de lisse
# No country detected in biscuiterie de chambord
# No country detected in bretagne
# No country detected in trichebray bocage
# No country detected in 24100 bergerac dordogne aquitaine
# No country detected in hollande
# No country detected in bretagne
# No country detected in saint gerand 56 le pouzin 07
# No country detected in aceitunas cazorla
# No country detected in bassin de l adour
# No country detected in trichebray bocage
# No country detected in bd de l europe 67210 obernai alsace
# No country detected in z i du verdier 19210 lubersac
# No country detected in bretagne
# No country detected in acetifici italiani modena carpi
# No country detected in auvergne
# No country detected in conditionne dans les pyrenees atlantique
# No country detected in 85600 bouffere vendee
# No country detected in bretagne
# No country detected in haute savoie
# No country detected in bretagne
# No country detected in thonon
# No country detected in lactalis nestle ultra frais mdd filiale groupe lactalis za les placis 35230 bourgarre fr 47 185 001 ce
# No country detected in franche comte
# No country detected in swaziland
# No country detected in europe
# No country detected in les p tits amoureux 79160 ardin
# No country detected in plomelin
# No country detected in 47200 virazeil lucien georgelin
# No country detected in st medard d eyrans
# No country detected in 13400 aubagne
# No country detected in 85430 la boissiere des landes
# No country detected in bretagne 22170
# No country detected in montayral
# No country detected in sas conserves stephan 22202 guingamp
# No country detected in 47200 virazeil
# No country detected in bretagne
# No country detected in chalais
# No country detected in maison briau bp 104 47931 agen cedex
# No country detected in made in europe
# No country detected in nord pas de calais
# No country detected in bretagne
# No country detected in saint aignan de grand lieu
# No country detected in agidra bp 156 69801 saint priest
# No country detected in larressore
# No country detected in larressore
# No country detected in val de loire
# No country detected in saint symphorien de lay
# No country detected in sarre union
# No country detected in csqa 227931
# No country detected in fabrique affine et conditionne dans la zone d appellation d origine affine par pfce 25170 laverney conditionne par la fromagerie de clerval 25340 santoche pfce 25170 laverney laverney pfce fromagerie de clerval 25340 santoche doubs
# No country detected in franche comte
# No country detected in emb 59094
# No country detected in auchan production
# No country detected in 42470 saint symphorien de lay
# No country detected in bretagne finistere landivisiau
# No country detected in les mates
# No country detected in 33290 blanquefort
# No country detected in taninges haute savoie
# No country detected in alsace
# No country detected in romans
# No country detected in bretagne saumon zone industrielle kroas lesneven 29520 chateauneuf du faou bretagne saumon bretagne finistere chateauneuf du faou 29520 chateauneuf du faou
# No country detected in franche comte
# No country detected in vendee
# No country detected in 49500 segre
# No country detected in marseille
# No country detected in gourdon lot
# No country detected in anjou
# No country detected in rognes en provence
# No country detected in lettre f eure loir lettre h lot
# No country detected in bretagne quiberon
# No country detected in danmark
# No country detected in carros alpes maritimes
# No country detected in saint ouen
# No country detected in tahiti
# No country detected in st martin d abbat
# No country detected in lot et garonne estillac
# No country detected in louatre
# No country detected in louatre
# No country detected in abidjan cote d ivoire
# No country detected in fromagerie de la lemance
# No country detected in voiron isere 38500
# No country detected in berry
# No country detected in producteur gaec pacouinay 85420 oulmes
# No country detected in ile maurice
# No country detected in made in europe
# No country detected in europe
# No country detected in lectoure
# No country detected in les marmitons d etran 1 grande rue des salines bp 1000 dieppe 76370 martin eglise
# No country detected in douai nord
# No country detected in 13420 gemenos
# No country detected in 13420 gemenos
# No country detected in annecy epagny
# No country detected in annecy epagny
# No country detected in la fromagerie de la lemance za du haut agenais 47500 montayral
# No country detected in sphere production
# No country detected in sphere production
# No country detected in ce
# No country detected in la rochelle
# No country detected in pays basque
# No country detected in europe snack zi saint denis les lucs 85170 saint denis la chevasse
# No country detected in chalandray
# No country detected in belle ile en mer bretagne
# No country detected in belle ile en mer bretagne
# No country detected in estillac
# No country detected in 88200 saint etienne les remiremont
# No country detected in ile de groix
# No country detected in 33610 cestas
# No country detected in vendee chateau d olonne 85180
# No country detected in 56410 etel
# No country detected in loire atlantique 44
# No country detected in 93300 aubervilliers
# No country detected in bretagne cotes d armor
# No country detected in capt et fils fromagers depuis 1850 les fruitieres des bornes 274 route de la muraz 74930 arbusigny haute savoie rhone alpes
# No country detected in la riviere st louis
# No country detected in 83440 caillan
# No country detected in sanilhac
# No country detected in roanne
# No country detected in fance
# No country detected in 97220 les antilles
# No country detected in fleurance
# No country detected in fleurance
# No country detected in lot et garonne saint laurent 32500 fleurance
# No country detected in ateliers bio de provence 150 allee bellecour f 84200 carpentras
# No country detected in bretagne
# No country detected in monastere notre dame de compassion
# No country detected in brasserie artisanele du dauphine 33 rue champ roman 38400 saint martin d heres
# No country detected in 79 rue saint maur 75011 paris
# No country detected in st just st rambert
# No country detected in epinay
# No country detected in la ferme de la madiere guilleville 28310
# No country detected in arras soup ideale
# No country detected in arras soup ideale
# No country detected in haute saone
# No country detected in lonlay l abbaye
# No country detected in dijon
# No country detected in saint gilles croix de vie
# No country detected in saint gilles croix de vie
# No country detected in bretagne
# No country detected in ardeche
# No country detected in vitre
# No country detected in dammarie les lys
# No country detected in saint jean le blanc
# No country detected in bretagne morbihan
# No country detected in rohan morbihan bretagne
# No country detected in bretagne bretagne morbihan
# No country detected in marseille
# No country detected in epinay sous semart
# No country detected in epinay sous senart
# No country detected in poitou charentes
# No country detected in castelsarrasin
# No country detected in 27750 la couture boussey
# No country detected in 27750 la couture boussey
# No country detected in champdeniers deux sevres
# No country detected in ardin poitou charentes
# No country detected in vezelay
# No country detected in vezelay
# No country detected in vezelay
# No country detected in earl oeufs bio buech gautier fabrice le bersac 05700 serres
# No country detected in europe
# No country detected in chagny bourgogne
# No country detected in chagny bourgogne
# No country detected in montreuil le gast 35
# No country detected in montreuil le gast 35
# No country detected in montreuil le gast 35
# No country detected in eu
# No country detected in eu
# No country detected in saint felix de lunel aveyron
# No country detected in 37530 charge
# No country detected in leyment
# No country detected in 31320 castanet tolosan sud ouestfr
# No country detected in toussieux
# No country detected in finistere
# No country detected in gironde izon
# No country detected in vidin
# No country detected in plovdiv b'lgariia
# No country detected in slovenija
# No country detected in rionegro antioquia
# No country detected in wertform hamburg
# No country detected in warstein
# No country detected in pasta brema 1 35010 san pietro in gu
# No country detected in eu
# No country detected in erding
# No country detected in d 67574 osthofen
# No country detected in produit dans l u e par mars r
# No country detected in gemany europe
# No country detected in 09599 fraiberg ul leiptsiger 48 germaniia
# No country detected in tyslkland 09599 fraiberg ul leiptsiger 48 germaniia
# No country detected in 09599 fraiberg ul leiptsiger 48 germaniia
# No country detected in thalfang
# No country detected in bad vilbel
# No country detected in quellort berkersheim
# No country detected in berlin
# No country detected in alemanha
# No country detected in meschede grevenstein
# No country detected in 41415 neuss
# No country detected in duitsland
# No country detected in duitsland
# No country detected in bad adelholzen
# No country detected in raiponce cavaillon
# No country detected in turkei
# No country detected in rapunzel naturkost 87764legau deutshland
# No country detected in griekenland
# No country detected in hamburg
# No country detected in hamburg
# No country detected in hamburg
# No country detected in hamburg
# No country detected in hamburg
# No country detected in hamburg
# No country detected in munchenweiler
# No country detected in parma
# No country detected in esslingen
# No country detected in krombach
# No country detected in konditerskaia fabrika ferrero s vorsha sobinskii r n vladimirskaia obl 601211 rossiia
# No country detected in germaniia
# No country detected in krumbach
# No country detected in farmer s snack gmbh beckedorfer bogen 27 21218 seevetal duitsland
# No country detected in 76676 graben neudorf
# No country detected in gustrow
# No country detected in gustrow
# No country detected in europe
# No country detected in 23970 wismar
# No country detected in 23970 wismar
# No country detected in braunschweig
# No country detected in stralsund
# No country detected in rosche
# No country detected in rosche
# No country detected in eu
# No country detected in emsdetten
# No country detected in emsdetten
# No country detected in eu
# No country detected in eu
# No country detected in danmark
# No country detected in chorin
# No country detected in schnitzer gmbh marlener str 9 77656 offenburg duitsland
# No country detected in d 36039 fulda
# No country detected in 85088 vohburg
# No country detected in holland
# No country detected in venlo nederland
# No country detected in lassan mecklenburg vorpommern
# No country detected in 85625 glonn
# No country detected in d 87724 ottobeuren
# No country detected in turkei
# No country detected in thuringen
# No country detected in hamburg
# No country detected in hamburg
# No country detected in hamburg
# No country detected in baden wurttemberg
# No country detected in b'lgariia
# No country detected in duitsland bergisch gladbach
# No country detected in d 50306 bruhl
# No country detected in bad oldesloe schleswig holstein
# No country detected in munchen
# No country detected in muchen
# No country detected in moskva rossiia
# No country detected in piding bayern
# No country detected in piding bayern
# No country detected in schoppingen
# No country detected in turkei
# No country detected in turkei
# No country detected in heubach
# No country detected in 95645 waldsassen
# No country detected in idem
# No country detected in deuschland
# No country detected in hamburg
# No country detected in brandenburg
# No country detected in holland
# No country detected in teegschwendner heidestrasse 26 d 53340 meckenheim
# No country detected in grand bretagne
# No country detected in britain
# No country detected in munster
# No country detected in munster
# No country detected in munster
# No country detected in munster
# No country detected in telgte
# No country detected in mind sweets gmbh arndtstr 34 10965 berlin duitsland
# No country detected in germaniia
# No country detected in berlin
# No country detected in berlin
# No country detected in berlin
# No country detected in berlin
# No country detected in holland
# No country detected in hamburg
# No country detected in hamburg
# No country detected in monchengladbach
# No country detected in dinslaken wildberg schwarzwald
# No country detected in reutlingen sessler getreidemuhle oferdingen gmbh
# No country detected in 40235 dusseldorf
# No country detected in monchengladbach
# No country detected in nurnberg
# No country detected in heilbronn
# No country detected in holland
# No country detected in kassel
# No country detected in abarzuza navarra
# No country detected in ul krasnoflotskaia g sergiev posad moskovskaia obl rossiia 141300
# No country detected in rossiia
# No country detected in rossiia
# No country detected in territoriia svobodnoi ekonomicheskoi zony sherrizon solnechnogorskii raion moskovskaia oblast' rossiia
# No country detected in nizhnii novgorod rossiia
# No country detected in nizhnii novgorod rossiia
# No country detected in sobinskii raion vladimirskaia oblast' rossiia
# No country detected in ekaterinburg rossiia
# No country detected in sankt peterburg rossiia
# No country detected in g izhevsk udmurtskaia respublika rossiia
# No country detected in rossiia moskva ul rustaveli 127254
# No country detected in gorbunkovskoe sp lomonosovskii raion leningradskaia oblast' rossiia
# No country detected in griazovets vologodskaia oblast' rossiia
# No country detected in griazovets vologodskaia oblast' rossiia
# No country detected in serpukhov moskovskaia oblast' rossiia
# No country detected in sankt peterburg rossiia
# No country detected in sankt peterburg rossiia
# No country detected in moskva rossiia
# No country detected in sankt peterburg rossiia
# No country detected in rossiia
# No country detected in sankt peterburg rossiia
# No country detected in krasnoarmeiskii raion krasnodarskii krai rossiia khutor protichka protichka
# No country detected in sankt peterburg rossiia
# No country detected in rossiia sankt peterburg
# No country detected in rossiia moskva nizhnii novgorod bashkortostan ufa krasnodarskii krai timashevsk krasnoiarskii krai nazarovo omskaia oblast' omsk vladimir vladimirskaia oblast' iur'ev pol'skii
# No country detected in iaroslavl' rossiia
# No country detected in g gatchina leningradskaia obl rossiia
# No country detected in gatchina leningradskaia oblast' rossiia
# No country detected in rossiia
# No country detected in rossiia
# No country detected in moskva rossiia
# No country detected in lebedian' lipetskaia oblast' rossiia
# No country detected in lebedian' lipetskaia oblast' rossiia
# No country detected in lebedian' lipetskaia oblast' rossiia
# No country detected in ul matrosova lipetskaia oblast' rf 399610
# No country detected in moskva rossiia
# No country detected in rossiia penzenskaia oblast' g nizhnii lomov
# No country detected in rossiia
# No country detected in g shchiolkovo moskovskaia obl rf
# No country detected in lebedian' lipetskaia oblast' rossiia
# No country detected in rossiia g lebedian' lipetskaia oblast'
# No country detected in g belgorod rossiia
# No country detected in otradnoe kirovskii raion leningradskaia oblast' rossiia
# No country detected in otradnoe kirovskii raion leningradskaia oblast' rossiia
# No country detected in ul transportnikov g berezovskii sverdlovskaia obl 623703 rossiia
# No country detected in g voronezh voronezhskaia obl rossiia
# No country detected in voronezh voronezhskaia oblast' rossiia
# No country detected in p roshchino sosnovskii raion cheliabinskaia oblast' rossiia
# No country detected in p bykovo ramenskii raion moskovskaia oblast' rossiia
# No country detected in lytkarino moskovskaia oblast' rossiia
# No country detected in rossiia
# No country detected in liubertsy moskovskaia oblast' rossiia
# No country detected in rossiia
# No country detected in moskva rossiia
# No country detected in rossiia belgorod
# No country detected in ul lavochkina moskva rossiia
# No country detected in moskva rossiia
# No country detected in g zelenograd g moskva 124489 rossiia
# No country detected in moskva rossiia
# No country detected in rudnia smolenskaia oblast' rossiia
# No country detected in posiolok molkombinata g rudnia rudnia smolenskaia oblast' rossiia
# No country detected in g bronnitsy moskovskaia obl rossiia
# No country detected in ul vnukovskaia g dmitrov moskovskaia obl 141800 rf
# No country detected in pos nekrasovskii dmitrovskii r n moskovskaia oblast' rossiia
# No country detected in pos nekrasovskii dmitrovskii r n moskovskaia oblast' rossiia 141865
# No country detected in ul ushakova pos nekrasovskii dmitrovskii r n moskovskaia oblast' rossiia
# No country detected in moskva rossiia
# No country detected in p izmailovo izmailovo leninskii raion moskovskaia oblast' rossiia
# ...
# No country detected in cabete casa agricula
# No country detected in coresa conserveiros reunidos s a escritorio central amoreiras plaza rua prof carlos alberto mota pinto n 9 4 c 1070 374 lisboa
# No country detected in serra da estrela
# No country detected in lisboa
# No country detected in sao miguel acores
# No country detected in uniao europeia
# No country detected in uniao europeia
# No country detected in guimaraes
# No country detected in ulme
# No country detected in uniao europeia u e
# No country detected in danmark
# No country detected in 2650 hvidovre danmark
# No country detected in nexo bornholm danmark
# No country detected in danmark
# No country detected in europe
# No country detected in amsterdam
# No country detected in fredersborg danmark
# No country detected in danmark
# No country detected in amsterdam
# No country detected in vejle
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in kutno polska
# No country detected in kutno polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in scandic food sp z o o ul filtrowa 53 02 057 warszawa
# No country detected in eu
# No country detected in alba
# No country detected in republica slovaca
# No country detected in vengriia
# No country detected in made in eu
# No country detected in made in eu
# No country detected in jacob hooy limmen holland
# No country detected in maurice
# No country detected in maurice
# No country detected in maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in taroudant
# No country detected in contres
# No country detected in blida
# No country detected in cote d ivoire
# No country detected in cote d ivoire
# No country detected in tunis
# No country detected in briouze
# No country detected in laval quebec
# No country detected in sadafco
# No country detected in uae
# No country detected in dubai uae
# No country detected in cehia
# No country detected in angletere
# No country detected in almaty
# No country detected in prc
# No country detected in Zhong Guo Zhi Zao
# No country detected in Zhong Hua Ren Min Gong He Guo
# No country detected in envasado en toledo
# No country detected in Su Zhou ,Zhong Guo
# No country detected in eu
# No country detected in bny brq
# No country detected in bt ym ySHrAl
# No country detected in tschechische republik
# No country detected in skane sverige
# No country detected in linkoping
# No country detected in sverige
# No country detected in eu
# No country detected in eu
# No country detected in nederlanderna
# No country detected in grado dalarna sweder
# No country detected in sverige norge
# No country detected in oatly ab foretagsvagen 42 26151 landskrona zweden
# No country detected in vichuga ivanovskaia oblast' rossiia
# No country detected in chocolat bernrain ch 8280 kreuzlingen
# No country detected in estavayer lait sa ch 1470 estavayer le lac
# No country detected in fenaco 1038 bercher
# No country detected in elsa
# No country detected in suisses
# No country detected in lichtenstein
# No country detected in emmi luzern
# No country detected in suica
# No country detected in allmagne
# No country detected in vosges
# No country detected in itancourt
# No country detected in vosges
# No country detected in vittel
# No country detected in alsace nord pas de calais
# No country detected in la fromagerie moleson sa ch 1694 orsonnens
# No country detected in hollande
# No country detected in hollande
# No country detected in lichtenstein
# No country detected in arisdorf bl
# No country detected in braziliia
# No country detected in jowa ag ch 8604 wolketswil
# No country detected in bischofszell ch
# No country detected in biscotte sa 1184 vinzel producteur zwygart laurent
# No country detected in micarna
# No country detected in meilen zh
# No country detected in mondelez eu b2b2c stationsstraat 100 2800 mechelen
# No country detected in rossiia
# No country detected in vervins
# No country detected in pokrov petushinskii raion vladimirskaia oblast' rossiia
# No country detected in blois
# No country detected in mondelez international
# No country detected in rossiia leningradskaia oblast' lomonosovskii raion proizvodstvennaia zona gorelovo
# No country detected in belgie
# No country detected in pokrov vladimirskaia oblast' rossiia
# No country detected in pokrov petushinskii raion vladimirskaia oblast' rossiia
# No country detected in zuger frischkase ag oberburen
# No country detected in valparaiso
# No country detected in braziliia
# No country detected in torino
# No country detected in 76136 mont saint aignan
# No country detected in portogallo
# No country detected in osellsa
# No country detected in vigano di gaggiano
# No country detected in pacinotti 25 37057 san giovanni lupatoto
# No country detected in bergame
# No country detected in sept sanpellegrino s p a sede legale localita ruspino 24016 san pellegrino terme bg
# No country detected in italiia muggia
# No country detected in ialie contrada colle delle api 100 a 86100 campobasso
# No country detected in brescia
# No country detected in mantova
# No country detected in chiusanico
# No country detected in itaien
# No country detected in ciano d enza canossa re
# No country detected in inghilterra regno unito
# No country detected in d 48599 germania
# No country detected in germania
# No country detected in cremona
# No country detected in produit
# No country detected in brescia
# No country detected in aldein
# No country detected in via tonale 21 a albano s alessandro bg stabilimento di proprieta parmalat
# No country detected in italiia
# No country detected in parma
# No country detected in stabilimento castiglione delle stiviere mn
# No country detected in rivarolo de re
# No country detected in degelis quebec
# No country detected in barcelona
# No country detected in barcelona
# No country detected in de th 601 eg
# No country detected in alicante
# No country detected in madrid
# No country detected in madrid
# No country detected in sierra de granda 33199 siero asturias
# No country detected in barcelona
# No country detected in barcelona
# No country detected in palencia espanha
# No country detected in ibercacao s a u
# No country detected in valencia
# No country detected in utebo saragoca espanha
# No country detected in madrid
# No country detected in murcia
# No country detected in autol la rioja
# No country detected in girona
# No country detected in albacete
# No country detected in madrid
# No country detected in valencia
# No country detected in valencia
# No country detected in cartagena
# No country detected in valencia
# No country detected in valencia
# No country detected in madrid
# No country detected in granollers barcelona
# No country detected in barcelona espanha
# No country detected in barcelona
# No country detected in barcelona
# No country detected in leon
# No country detected in miquel alimentacio grup
# No country detected in rgseaa 1664j para hd covalco 08403 granollers barcelona
# No country detected in valencia
# No country detected in jijona
# No country detected in granollers y en montmelo
# No country detected in pontevedra galicia
# No country detected in vallodolid
# No country detected in tarragona
# No country detected in oudenhoorn comunidad bernisse holanda meridional paises bajos
# No country detected in benifla
# No country detected in sesena nuevo toledo provincia castilla la mancha
# No country detected in murcia
# No country detected in barcelona
# No country detected in alicante
# No country detected in murcia
# No country detected in murcia
# No country detected in san martin del rey aurelio asturias
# No country detected in maliano cantabria
# No country detected in valencia
# No country detected in valencia espanha
# No country detected in espanha
# No country detected in murcia
# No country detected in bocairent valencia
# No country detected in bocairent valencia
# No country detected in holland
# No country detected in castilla leon
# No country detected in 156 3300 02198 08 09 2014
# No country detected in valencia
# No country detected in elche alicante
# No country detected in barcelona
# No country detected in les franqueses del valles
# No country detected in albacete
# No country detected in deltebre tarragona
# No country detected in pinoso alicante
# No country detected in cuenca
# No country detected in irun
# No country detected in alicante
# No country detected in coruna
# No country detected in bunol
# No country detected in andalucia
# No country detected in embutidos la nuncia toledo
# No country detected in aragon
# No country detected in aragon
# No country detected in la rioja
# No country detected in lodosa navarra
# No country detected in escuris sl c bayuca s n puebla del caraminal a coruna
# No country detected in cordoba
# No country detected in valladolid
# No country detected in casa terradellas barcelona
# No country detected in vinaros castellon
# No country detected in vinaros castellon
# No country detected in lodosa
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in valencia
# No country detected in covi union europeenne
# No country detected in brasserie de gayant
# No country detected in u e
# No country detected in gumlink confectionery a s union europeenne
# No country detected in sas frial
# No country detected in horst limburgo horst aan de maas limburgo paises bajos
# No country detected in sibell jacinto benavente union europeenne
# No country detected in iscal sugar
# No country detected in campofrio food group
# No country detected in sear sociedade europeia de arroz
# No country detected in locmaria
# No country detected in pag sl union europeenne
# No country detected in initia food sas union europeenne
# No country detected in coroos conserven union europeenne
# No country detected in burgos espanha
# No country detected in dordrecht holland
# No country detected in europeenne de condiments
# No country detected in manuel serra s a
# No country detected in global green international union europeenne
# No country detected in almeria
# No country detected in santona cantabria
# No country detected in valencia
# No country detected in asturias
# No country detected in girona
# No country detected in 43320 loudes
# No country detected in nitra slovensko
# No country detected in usov ceska republika
# No country detected in czech
# No country detected in ceske budejovice budweis
# No country detected in ceske budejovice republique tcheque
# No country detected in republique tcheque plzensky prazdroj a s u prazdroje 7 30497 pilsen
# No country detected in moskva rossiia
# No country detected in turkiye
# No country detected in ankara turkiye
# No country detected in turkei
# No country detected in turkei
# No country detected in turkei
# No country detected in kocaeli
# No country detected in gebze kocaeli
# No country detected in almanya
# No country detected in turkei
# No country detected in turkiye
# No country detected in turkei
# No country detected in turkei
# No country detected in turkei
# No country detected in turkei
# No country detected in eu
# No country detected in turkiye
# No country detected in pozanti adana
# No country detected in turquia
# No country detected in turquia
# No country detected in turquia
# No country detected in istanbul
# No country detected in turkiye
# No country detected in vanka kawat elbe 13 19 2491 bt den haag nederland
# No country detected in nederland
# No country detected in swartberg rotterdam
# No country detected in rotterdam
# No country detected in fabrique aux pays bas
# No country detected in eu
# No country detected in u e
# No country detected in europe
# No country detected in hollande
# No country detected in schiedam holland
# No country detected in hollland
# No country detected in hallum nederland
# No country detected in nederland
# No country detected in theha bv postbus 34 3840 aa harderwijk nederland
# No country detected in breda hollande
# No country detected in holland
# No country detected in holland
# No country detected in non renseigne
# No country detected in jacobs douwe egberts amsterdam
# No country detected in inconnu
# No country detected in berkel enschot tilburgo brabante septentrional paises bajos
# No country detected in udea bv 5460 ae veghel nederland
# No country detected in ekoplaza 5460 ae veghel nederland
# No country detected in 5460 ae veghel nederland
# No country detected in udea bv postbus 244 5460 ae veghel nederland
# No country detected in corn candies bv de hoefsmid 6 1851 pz heiloo nederland
# No country detected in corn candies bv de hoefsmid 6 1851 pz heiloo nederland
# No country detected in corn candies bv de hoefsmid 6 1851 pz heiloo nederland
# No country detected in corn candies bv de hoefsmid 6 1851 pz heiloo nederland
# No country detected in organic flavour company bv turbinestraat 12 3903 lw veenendaal nederland
# No country detected in organic flavour company bv turbinestraat 12 3903 lw veenendaal nederland
# No country detected in billy natuurbakkerij van leeuwenhoeklaan 6 9207 je drachten nederland
# No country detected in distribuidor harderwijk gueldres paises bajos
# No country detected in amsterdam
# No country detected in eu
# No country detected in holanda
# No country detected in verenigd koninkrijk
# No country detected in non indique
# No country detected in europe
# No country detected in europe
# No country detected in oppers 58 8471 zm wolvega nerherlands
# No country detected in fz organic food oppers 58 8471 zm wolvega nederland
# No country detected in eu
# No country detected in e u
# No country detected in eu
# No country detected in distribuidor ijsselstein utrecht provincia paises bajos
# No country detected in dijon
# No country detected in hollande
# No country detected in becky s bv postbus 37771 1030 bj amsterdam pays bas
# No country detected in hulsbos 3 5431 nz cuijk nederland
# No country detected in vaals nederland
# No country detected in de aviateur banketbakkerijen bv 1720 aa broek op langendijk nederland
# No country detected in the organic factory bv mastbos 21 5531 mx bladel nederland
# No country detected in haulerwijk nederland
# No country detected in haulerwijk nederland
# No country detected in turfsteker 6 8433 ht harderwijk nederland
# No country detected in machandel bv turfsteker 6 8433 ht haulerwijk nederland
# No country detected in haulerwijk ooststellingwerf frisia provincia paises bajos
# No country detected in cloetta holland bv 4900 ab oosterhout nederland
# No country detected in de appelaere bv philipsweg 2 4508 np waterlandkerkje nederland
# No country detected in holanda
# No country detected in sappemeer hoogezand sappemeer groninga provincia paises bajos
# No country detected in holland
# No country detected in droste bv vaassen nederland
# No country detected in eu
# No country detected in amsterdam nederland
# No country detected in amsterdam nederland
# No country detected in nederland
# No country detected in eu
# No country detected in europe
# No country detected in de smaakspecialist molenstraat 67 4851 se ulvenhout nederland
# No country detected in driekant langehofstraat 23 7201 ht zutphen nederland
# No country detected in nederland
# No country detected in belgie
# No country detected in paises baixos
# No country detected in orion je2igsangongjang
# No country detected in laos
# No country detected in pthumthaanii praethsaithy
# No country detected in laos
# No country detected in ostereich
# No country detected in avstriia
# No country detected in avstriia
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in osterrreich
# No country detected in bretagne
# No country detected in vienna
# No country detected in les essarts
# No country detected in morroco
# No country detected in australiaq
# No country detected in australian
# No country detected in southbank victoria
# No country detected in product of new zealand
# No country detected in ontario
# No country detected in carib brewery ltd champs fleurs trinidad w i

# %%
print_random(DATA_CLEANED[DATA_CLEANED["manufacturing_places_tags"].str.len() != 0 ]["manufacturing_places_tags"], 10)
# Out:
# 308767      [spain]
# 245020     [france]
# 238078     [france]
# 184142    [germany]
# 280086    [belgium]
# 219845     [france]
# 195882     [france]
# 308964      [spain]
# 311890      [spain]
# 101026      [spain]
# Name: manufacturing_places_tags, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["manufacturing_places_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 286125, 89.20%
# Number of value removed = 1848, 0.58%

# %% [markdown]
# la majorité des lignes ont été traitées
# Il manque cependant 1848 lignes,
# Cela est principalement dû à la présence du nom de ville ou de région difficile à traiter
# Puisque cela ne représente que 5% du nombre de lignes initialement remplies et 0.6% du nombre total de lignes,
# j'ai décidé de ne pas aller plus loin

# %% [markdown]
# ### Netoyage de l'origine des produits
# Exactement la même démarche que pour les lieux de transformations

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["origins_tags"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 298619, 93.09%

# %%
DATA_CLEANED["origins_tags"] = DATA['origins_tags'].apply(is_str)
DATA_CLEANED["origins_tags"] = DATA_CLEANED['origins_tags'].apply(str_replace, args=(",", " "))
DATA_CLEANED["origins_tags"] = DATA_CLEANED["origins_tags"].apply(lower_case)
DATA_CLEANED["origins_tags"] = DATA_CLEANED["origins_tags"].apply(remove_accent)
DATA_CLEANED["origins_tags"] = DATA_CLEANED["origins_tags"].apply(find_country, args=(COUNTRIES,))
DATA_CLEANED["origins_tags"] = DATA_CLEANED["origins_tags"].apply(create_list)
# Out:
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in grande bretagne
# No country detected in saudi
# No country detected in several countries
# No country detected in more than one country
# No country detected in california
# No country detected in united states of america
# No country detected in arden hilss minnesota
# No country detected in hackettstown nj
# No country detected in californie
# No country detected in massachusetts
# No country detected in us
# No country detected in almendras california estados unidos
# No country detected in almendras california estados unidos
# No country detected in north america
# No country detected in europe
# No country detected in ivory coast
# No country detected in porc du royaume uni
# No country detected in great britain
# No country detected in importe
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in quebec cnd
# No country detected in quebec
# No country detected in st hubert quebec
# No country detected in quebec
# No country detected in quebec
# No country detected in parry sound on
# No country detected in saint leonard quebec
# No country detected in toronto ontario
# No country detected in fait a partir de farines de ble du quebec
# No country detected in quebec
# No country detected in ceylan
# No country detected in e u a
# No country detected in e u a
# No country detected in e u a
# No country detected in e u a
# No country detected in montreal
# No country detected in isvicre
# No country detected in eu
# No country detected in boeuf du royaume uni
# No country detected in thailandia
# No country detected in californie
# No country detected in grande bretagne
# No country detected in londonderry
# No country detected in poulet du royaume uni
# No country detected in colin d alaska merlu blanc
# No country detected in e u a
# No country detected in e u a
# No country detected in e u a
# No country detected in loch sunart
# No country detected in great britain
# No country detected in indetermine undetermined
# No country detected in more than one country
# No country detected in u s a
# No country detected in quebec
# No country detected in l eclicherie
# No country detected in beurre aop charentes poitou
# No country detected in viande de boeuf union europeenne
# No country detected in hors union europeenne
# No country detected in eu
# No country detected in 22400
# No country detected in wales
# No country detected in holand
# No country detected in south west atlantic
# No country detected in south west atlantic
# No country detected in noirmoutier
# No country detected in us grown
# No country detected in great britain
# No country detected in quebec
# No country detected in e u a
# No country detected in amsterdam the netherland
# No country detected in quebec
# No country detected in quebec
# No country detected in edmonron alberta
# No country detected in longueuil quebec
# No country detected in kitchener on
# No country detected in montreal quebec
# No country detected in manitoba cdn
# No country detected in belgian chocolate
# No country detected in chester hill ma stockbridge vt southfield ma bennington
# No country detected in tibet region du qinghai
# No country detected in mississauga on
# No country detected in jus de truffe noire tuber melanosporum
# No country detected in quebec
# No country detected in quebec
# No country detected in toronto ontario
# No country detected in london grande bretagne
# No country detected in quebec
# No country detected in pacific ocean
# No country detected in st theodore d acton quebec
# No country detected in asie pour le fruit de moines
# No country detected in e u a
# No country detected in u s a
# No country detected in vancouver
# No country detected in vancouver bc
# No country detected in eu
# No country detected in amerique latine
# No country detected in eu
# No country detected in montargis
# No country detected in citron de sicile
# No country detected in californie
# No country detected in sudamerika
# No country detected in union europeenne hors union europeenne
# No country detected in bayerisch
# No country detected in cotes de gascogne
# No country detected in bas armagnac
# No country detected in fromagerie de grieges
# No country detected in bordelais
# No country detected in vallee des gaves
# No country detected in bordeaux
# No country detected in abidjan
# No country detected in trasierra
# No country detected in tourouzelle aude minervois
# No country detected in champagne
# No country detected in chevillon champagne
# No country detected in coueron
# No country detected in viande de porc union europeenne
# No country detected in hollande
# No country detected in queyssac dordogne
# No country detected in colin d alaska theragra chalcogramma
# No country detected in mushrooms
# No country detected in alsace
# No country detected in holanda
# No country detected in bourgogne
# No country detected in murcia
# No country detected in monterey california
# No country detected in kakao sudamerika
# No country detected in champagne
# No country detected in ocean pacifique fao 87
# No country detected in chocolat noir callebaut a 54 9
# No country detected in chocolat noir callebaut a 54 9
# No country detected in chocolat noir callebaut a 54 9
# No country detected in chocolat noir callebaut a 54 9
# No country detected in chocolat noir callebaut a 54 9
# No country detected in mascarpone sans lactose chocolat callebaut noir a 54 9
# No country detected in alba la romaine
# No country detected in saumur
# No country detected in bretagne
# No country detected in sill
# No country detected in turkiye
# No country detected in ankara turkiye
# No country detected in gorod izhevsk udmurtskaia respublika rossiia
# No country detected in jura
# No country detected in earth
# No country detected in rossiia
# No country detected in saumon atlantique salmo salar
# No country detected in viande de porc britannique grande bretagne
# No country detected in ceylan
# No country detected in inconnu
# No country detected in amerique latine
# No country detected in ocean pacifique
# No country detected in variable
# No country detected in saint domingue
# No country detected in berlin morizplatz
# No country detected in asturias
# No country detected in non gmo soy beans salt wheat flovour
# No country detected in non gmo soy bean wheat flour salt water
# No country detected in inconnue
# No country detected in cote d ivoire
# No country detected in quebec
# No country detected in karaman turkiye
# No country detected in istanbul turkiye
# No country detected in turkiye
# No country detected in istanbul
# No country detected in u s a
# No country detected in strasbourg cedex 2
# No country detected in saint laurent du maroni
# No country detected in saint laurent du maroni
# No country detected in sudamerika sudostasien
# No country detected in afrika
# No country detected in ocean pacifique fao 61 fao 67
# No country detected in ocean pacifique fao 61 fao 67
# No country detected in ocean pacifique
# No country detected in eu
# No country detected in asie
# No country detected in eu
# No country detected in holanda
# No country detected in fao 71 ocean pacifique centre ouest
# No country detected in eu
# No country detected in u e
# No country detected in oeufs union europeenne
# No country detected in viande bovine francaise
# No country detected in mediterranee
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in originaires et non originaires de la ce
# No country detected in colin d alaska theragra chalcogramma ocean pacifique fao 61 fao 67
# No country detected in 76153 maromme
# No country detected in kakao trinidad trinidad und tobago
# No country detected in fao 27
# No country detected in ocean pacifique fao 71
# No country detected in eu
# No country detected in eu agriculture non eu agriculture
# No country detected in eu
# No country detected in eu
# No country detected in non precise
# No country detected in fao 27 sub area viii fao 27 sub area vii
# No country detected in holland
# No country detected in holland
# No country detected in viande de porc union europeenne
# No country detected in viandes union europeenne
# No country detected in saint mars la jaille
# No country detected in niederland
# No country detected in holland
# No country detected in eu
# No country detected in deutsche landwirtschaft
# No country detected in alemanha
# No country detected in ardeche
# No country detected in north west atlantic fao no 21
# No country detected in holanda
# No country detected in ocean pacifique mer de bering golfe d alaska
# No country detected in fao 47
# No country detected in fao 47
# No country detected in angers
# No country detected in fao67
# No country detected in ocean pacifique fao 67
# No country detected in fao 27
# No country detected in fao71
# No country detected in fao34
# No country detected in fao 67
# No country detected in fao 77 fao 81 fao 87
# No country detected in europe
# No country detected in fao34
# No country detected in ocean atlantique ocean pacifique
# No country detected in colin d alaska
# No country detected in fromagerie de ducey
# No country detected in macedoine
# No country detected in north east atlantic fao 27 la fao 27 lb
# No country detected in turquia
# No country detected in sicile
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in atlantique nord ouest
# No country detected in fao 51 fao 57 fao 27
# No country detected in eu
# No country detected in inconnue
# No country detected in corse
# No country detected in eu
# No country detected in eu
# No country detected in unknown
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in nicht eu landwirtschaft
# No country detected in eutschland
# No country detected in great britain
# No country detected in eu
# No country detected in eu
# No country detected in fao 21
# No country detected in ocean pacifique centre ouest
# No country detected in bosnia
# No country detected in lainate
# No country detected in ellada
# No country detected in turtsiia
# No country detected in 25340 santoche
# No country detected in 89771 chailley
# No country detected in fao27 fao34 fao51 fao57 fao61 fao71 fao77
# No country detected in sao miguel acores
# No country detected in bayern
# No country detected in fao 61 fao 67 nordostpazifik nordwestpazifik
# No country detected in eu
# No country detected in kakao sudamerika
# No country detected in antilles francaises
# No country detected in nordrhein westfalen
# No country detected in origine certifiee sud ouest igp
# No country detected in holland
# No country detected in valencia
# No country detected in marocco
# No country detected in holanda
# No country detected in 84144 geisenhausen
# No country detected in gaec campagne beauregard 04700 lurs
# No country detected in turquia
# No country detected in region murau
# No country detected in uniao europeia
# No country detected in antilles francaises
# No country detected in fr antilles francaises
# No country detected in non indique
# No country detected in gers
# No country detected in grande bretagne
# No country detected in amerique du nord
# No country detected in nicht eu landwirtschaft
# No country detected in uca
# No country detected in midi pyrenees
# No country detected in amerique du nord
# No country detected in vin blanc riesling
# No country detected in viande de porc union europeenne
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne et hors union europeenne
# No country detected in cote d ivoire
# No country detected in saumon ocean pacifique
# No country detected in ce
# No country detected in d 33397 rietberg
# No country detected in fao 27
# No country detected in sardines sardina pilchardus
# No country detected in thes verts asie
# No country detected in amerique du sud
# No country detected in ocean pacifique fao 67
# No country detected in fao 67 fao 61
# No country detected in cotentin
# No country detected in u e
# No country detected in import
# No country detected in import
# No country detected in australian made
# No country detected in imported unknown
# No country detected in imported unknown
# No country detected in imported unknown
# No country detected in australa
# No country detected in bron alizee
# No country detected in kisslegg quelle krumbach naturell
# No country detected in malville
# No country detected in sel de guerande
# No country detected in antilles francaises
# No country detected in atlantique centre ouest
# No country detected in polska
# No country detected in pazifischer ozean fao 87 fao 77
# No country detected in kakao papua neuguinea
# No country detected in mazedonien
# No country detected in oceano pacifico
# No country detected in polska
# No country detected in espanna
# No country detected in sudamerica
# No country detected in importe
# No country detected in porc bretagne
# No country detected in sud americaine
# No country detected in antilles
# No country detected in atlantique nord fao 27 ocean pacifique fao 67
# No country detected in franca
# No country detected in mediterranee
# No country detected in penjab camargue
# No country detected in aisne
# No country detected in berry
# No country detected in eu
# No country detected in saumon rose ocean pacifique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in bateau santana 2014
# No country detected in ocean atlantique
# No country detected in atlantique
# No country detected in pacifique
# No country detected in ouest pacifique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in ocean atlantique
# No country detected in ocean pacifique
# No country detected in boeuf 100 francais
# No country detected in colin d alaska
# No country detected in pommes francaises
# No country detected in communaute europeenne
# No country detected in communaute europeenne
# No country detected in lait union europeenne
# No country detected in ble francais oeufs de poules francais
# No country detected in strasbourg
# No country detected in 97 de ble francais
# No country detected in ble francais 97 de la farine de ble
# No country detected in saint ouen 93589
# No country detected in en:e1422 en:e440 en:e412 en:e120 en:e160c en:e101
# No country detected in en:e440 en:e410 en:e412 en:e333 en:e120 en:e163
# No country detected in en:e1422 en:e440 en:e412 en:e141
# No country detected in en:e1422 en:e440 en:e410 en:e412 en:e160c en:e120 en:e163 en:e330 en:e331
# No country detected in en:e1200 en:e412 en:e440 en:e407 en:e415 en:e331 en:e330 en:e333 en:e950 en:e955
# No country detected in en:e1200 en:e440 en:e412 en:e407 en:e415 en:e950 en:e955
# No country detected in en:e1200 en:e412 en:e440 en:e407 en:e415 en:e331 en:e330 en:e333 en:e950 en:e955
# No country detected in en:e160 en:e163
# No country detected in en:e1442 en:e410 en:e331 en:e330
# No country detected in en:e1422 en:e440 en:e331 en:e330 en:e333
# No country detected in en:e330
# No country detected in en:e1422 en:e1442 en:e440 en:e407 en:e410 en:e331 en:e330
# No country detected in en:e407 en:e270 en:e950 en:e955
# No country detected in en:e440 en:e331 en:e330 en:e950 en:e955
# No country detected in en:e440 en:e415 en:e331 en:e330 en:e270 en:e950 en:e955 en:e960
# No country detected in en:e1422 en:e440 en:e407 en:e415 en:e331 en:e330 en:e270 en:e950 en:e955 en:e960
# No country detected in en:e1422 en:e1442 en:e160a en:e163 en:e330 en:e331
# No country detected in en:e412 en:e333 en:e330 en:e331
# No country detected in en:e415 en:e330 en:e331
# No country detected in en:e412 en:e407 en:e440 en:e120 en:e330 en:e331
# No country detected in en:e412 en:e407 en:e101 en:e330 en:e331
# No country detected in en:e1200 en:e412 en:e440 en:e407 en:e415 en:e331 en:e330 en:e333 en:e950 en:e955
# No country detected in landes
# No country detected in zone de peche le sor trondelag
# No country detected in pacifique n e pacifique n o
# No country detected in ocean pacifique
# No country detected in alaska ocean pacifique
# No country detected in pacifique
# No country detected in les iles hebrides
# No country detected in sud ouest
# No country detected in sel de camargue
# No country detected in sel de camargue
# No country detected in non indique
# No country detected in garantie boeuf francais controle
# No country detected in boeuf francais controle
# No country detected in himalaya
# No country detected in basmati long traditionnel
# No country detected in ocean pacifique
# No country detected in ocean pacifique
# No country detected in ocean pacifique
# No country detected in morue gadus macrocephalus ocean pacifique
# No country detected in pacifique
# No country detected in alaska
# No country detected in cabillaud ocean pacifique
# No country detected in ocean pacifique centre ouest
# No country detected in importation
# No country detected in anjou
# No country detected in communaute europeenne
# No country detected in pacifique
# No country detected in pacifique
# No country detected in bordeaux
# No country detected in amazonie
# No country detected in vittel
# No country detected in source hepar embouteille a vittel
# No country detected in auvergne
# No country detected in viande origine u e
# No country detected in volvic puy de dome
# No country detected in source clairvic
# No country detected in concentre
# No country detected in ble 100 francais
# No country detected in bayonne
# No country detected in grand sud ouest
# No country detected in sud ouest chalosse gers perigord quercy landes gascogne
# No country detected in import
# No country detected in quot produit d importation quot
# No country detected in source saint galmier
# No country detected in evian
# No country detected in evian
# No country detected in partiellement de st galmier
# No country detected in source saint galmier
# No country detected in saint galmier
# No country detected in deutchland
# No country detected in strasbourg
# No country detected in strasbourg
# No country detected in strasbourg
# No country detected in asie bassin mediterraneen
# No country detected in europe
# No country detected in asie bassin mediterraneen
# No country detected in u e
# No country detected in europe asie
# No country detected in citron sicile
# No country detected in nl
# No country detected in ce hors ce
# No country detected in gan 64290
# No country detected in monde
# No country detected in europe amerique latine
# No country detected in europe amerique latine
# No country detected in melanges de miels originaires et non originaires de la ce
# No country detected in pyrennees
# No country detected in communaute europeenne monde
# No country detected in melange de miels originaires et non originaires de la ce issu de l agriculture biologique
# No country detected in mayenne chateau gontier
# No country detected in colin d alaska merlu blanc
# No country detected in importation
# No country detected in importation
# No country detected in modene
# No country detected in bretagne
# No country detected in bretagne
# No country detected in importe
# No country detected in figeac
# No country detected in europe
# No country detected in gironde
# No country detected in cote d ivoire
# No country detected in amerique latine
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in u e
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in french arabic
# No country detected in normandie
# No country detected in mediterranee
# No country detected in frankrijk
# No country detected in mer du nord
# No country detected in ile maurice
# No country detected in mediterranee
# No country detected in cote d ivoire
# No country detected in bretagne
# No country detected in cote d ivoire
# No country detected in ocean atlantique
# No country detected in cote d ivoire
# No country detected in cote d ivoire
# No country detected in ostlicher pazifischer ozean
# No country detected in provence
# No country detected in chelles
# No country detected in cote d ivoire
# No country detected in franca
# No country detected in cote d ivoire
# No country detected in sorbiers
# No country detected in communaute europeenne
# No country detected in nutrition et sante sas bp 106 31250 revel
# No country detected in revel
# No country detected in normandie
# No country detected in huiles d olive union europeenne
# No country detected in vallee du rhone
# No country detected in importation
# No country detected in import
# No country detected in cote d ivoire
# No country detected in importation
# No country detected in bretagne
# No country detected in source sassoy plancoet
# No country detected in leognan
# No country detected in normandie
# No country detected in normandie
# No country detected in normandie
# No country detected in normandie
# No country detected in normandie
# No country detected in elabore en normandie
# No country detected in mediterranee
# No country detected in aigues mortes gard
# No country detected in mediterranee
# No country detected in lac leman
# No country detected in sel de guerande
# No country detected in amerique centrale
# No country detected in bateau galerien
# No country detected in saumon rose du pacifique
# No country detected in colin d alaska
# No country detected in communaute europeenne
# No country detected in mer du nord limfjord danois
# No country detected in bretagne
# No country detected in bayern
# No country detected in matiere premiere union europeenne
# No country detected in matiere premiere union europeenne
# No country detected in matiere premiere union europeenne
# No country detected in matiere premiere union europeenne
# No country detected in alsace
# No country detected in alpes roche des ecrins
# No country detected in importation
# No country detected in panses et pieds de boeuf union europeenne
# No country detected in deux sevres
# No country detected in thon blanc germon
# No country detected in importation
# No country detected in floride
# No country detected in thon albacore
# No country detected in cote d ivoire thon albavore
# No country detected in cote d ivoire thon albacore
# No country detected in en ce hors ce
# No country detected in colin d alaska theragra chalcogramma
# No country detected in amerique latine
# No country detected in union europeenne hors union europeenne
# No country detected in porc union europeenne
# No country detected in saumon atlantique salmo salar ocean atlantique
# No country detected in ocean pacifique centre ouest fao 71
# No country detected in amerique latine
# No country detected in ocean pacifique
# No country detected in ocean atlantique
# No country detected in colin d alaska theragra chalcogramma ocean pacifique
# No country detected in saumon rose ocean pacifique saumon ocean atlantique
# No country detected in saumon salmo salar
# No country detected in morue gadus macrocephalus ocean pacifique
# No country detected in saumon atlantique
# No country detected in thon blanc germon
# No country detected in non union europeenne
# No country detected in morue ocean atlantique
# No country detected in saint domingue
# No country detected in europe
# No country detected in viande bovine union europeenne
# No country detected in viande de veau union europeenne
# No country detected in monts du forez
# No country detected in amerique du sud eu
# No country detected in normandie
# No country detected in eu
# No country detected in lait francais
# No country detected in eu
# No country detected in eu
# No country detected in union europeenne hors union europeenne
# No country detected in farine francaise
# No country detected in farine de ble 100 francaise
# No country detected in farine de ble fabrication 100 francaise
# No country detected in ceylan
# No country detected in inconnue
# No country detected in saint genis laval
# No country detected in bourgogne
# No country detected in bretagne
# No country detected in cotes du roussillon villages tautavel
# No country detected in bellesta cotes du roussillon villages
# No country detected in provence
# No country detected in bretagne
# No country detected in franche comte
# No country detected in romans drome
# No country detected in ardeche
# No country detected in isigny
# No country detected in bordelais
# No country detected in amerique latine europe
# No country detected in importe du sri lanka agriculture sri lanka
# No country detected in viande de porc union europeenne
# No country detected in l emmental et le beurre proviennent de l union europeenne
# No country detected in morue gadus morhua
# No country detected in lieu alaska
# No country detected in modene
# No country detected in colin d alaska theragra chalcogramma ocean pacifique nord
# No country detected in colin d alaska theragra chalcogramma ocean pacifique nord
# No country detected in carotte celeri union europeenne
# No country detected in alaska
# No country detected in colin d alaska theragra chalcogramma ocean pacifique nord
# No country detected in colin d alaska theragra chalcogramma ocean pacifique nord
# No country detected in colin d alaska theragra chalcogramma ocean pacifique nord
# No country detected in u e
# No country detected in carcassonne
# No country detected in union europeenne amerique du sud
# No country detected in corse
# No country detected in camargue
# No country detected in franca
# No country detected in importation
# No country detected in viande union europeenne
# No country detected in igp
# No country detected in oeufs fermiers de loue
# No country detected in camembert de normandie aop
# No country detected in saint benoit
# No country detected in importation
# No country detected in importation
# No country detected in importation
# No country detected in importation
# No country detected in normandie
# No country detected in selon region d achat
# No country detected in creme francaise
# No country detected in colin d alaska
# No country detected in ocean atlantique fao 27 ocean pacifique fao 67
# No country detected in source de prahecq
# No country detected in kronoss sa
# No country detected in importation
# No country detected in farine de ble francaise
# No country detected in eau de source st benoit gazeifiee 88
# No country detected in cee communaute economique europeenne
# No country detected in europe
# No country detected in non indique
# No country detected in non pr2cis2e
# No country detected in normandie
# No country detected in colin d alaska
# No country detected in matieres premieres d importation
# No country detected in 35890 laille
# No country detected in importation
# No country detected in pastificio rana s p a san giovanni lupatoto verona
# No country detected in val de loire
# No country detected in importation
# No country detected in alaska
# No country detected in farine de ble union europeenne
# No country detected in corse
# No country detected in auvergne
# No country detected in gard aigues mortes union europeenne
# No country detected in farine complete de ble francaise
# No country detected in farine de ble francaise
# No country detected in bretagne
# No country detected in amerique latine europe
# No country detected in ardeche
# No country detected in st martin d abbat
# No country detected in non indique
# No country detected in pacifique ou atlantique
# No country detected in riz sauvage zizania aquatica
# No country detected in pays d oc
# No country detected in alaska
# No country detected in bretagne
# No country detected in cote d ivoire
# No country detected in ab agriculture biologique selection intermarche
# No country detected in beurre de bretagne
# No country detected in lait francais
# No country detected in poires williams du lot et garonne 65
# No country detected in champagne ardenne
# No country detected in lait francais
# No country detected in amerique latine europe
# No country detected in ocean pacifique fao 67 fao 61
# No country detected in ocean pacifique
# No country detected in champagne ardenne
# No country detected in importation
# No country detected in fao 27 fao 21 union europeenne hors union europeenne
# No country detected in amerique latine europe
# No country detected in eu
# No country detected in bretagne
# No country detected in bretagne
# No country detected in normandie
# No country detected in normandie
# No country detected in source vermont f 69730 cernay
# No country detected in conserve appertisee legume coeurs de palmier
# No country detected in normandie
# No country detected in cote d ivoire
# No country detected in normandie
# No country detected in beurre union europeenne
# No country detected in atlantique centre ouest
# No country detected in bretagne
# No country detected in amerique du sud
# No country detected in importe
# No country detected in importe du sri lanka
# No country detected in importe
# No country detected in union europeenne hors union europeenne
# No country detected in communaute europeenne
# No country detected in thon albacore
# No country detected in cote d ivoire
# No country detected in non eu
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne et hors union europeenne
# No country detected in amerique du sud
# No country detected in importation
# No country detected in importation
# No country detected in aiguillettes de poulet union europeenne
# No country detected in canard eleve et prepare dans le sud ouest
# No country detected in union europeenne hors union europeenne
# No country detected in ocean atlantique n e
# No country detected in alaska ocean pacifique
# No country detected in eaux minerales naturelles eaux minerales gazeuzes naturellement eaux minerales gazeuses naturellemnt aromatisees
# No country detected in amerique
# No country detected in amerique
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne non union europeenne
# No country detected in lentille verte du puys a o p
# No country detected in francaise en partie
# No country detected in saumon rose ocean pacifique
# No country detected in viande de porc union europeenne
# No country detected in farine de ble francais
# No country detected in union europeenne hors union europeenne
# No country detected in bretagne
# No country detected in caraibes
# No country detected in ameriques
# No country detected in saumon salmo salar
# No country detected in ab bio europeen fsc fr bio 10
# No country detected in agen
# No country detected in inconnu
# No country detected in point vert
# No country detected in au lait de normandie
# No country detected in normandie
# No country detected in farine de ble francais
# No country detected in amerique
# No country detected in import
# No country detected in farine de ble francaise
# No country detected in bretagne
# No country detected in bretagne
# No country detected in sources de soultzmatt
# No country detected in cote d ivoire
# No country detected in provence
# No country detected in cote d ivoire
# No country detected in agen region d agen aquitaine
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande porcine union europeenne
# No country detected in pays de la loire
# No country detected in cote d ivoire
# No country detected in cote d ivoire
# No country detected in cote d ivoire
# No country detected in viande de porc union europeenne
# No country detected in saumon oncorhynchus keta
# No country detected in thon listao
# No country detected in colin d alaska
# No country detected in communaute europeenne
# No country detected in union europeenne hors union europeenne
# No country detected in morue gadus morhua
# No country detected in floride
# No country detected in viande de porc union europeenne
# No country detected in bourgogne pommard
# No country detected in sud ouest
# No country detected in revel
# No country detected in 31250 revel
# No country detected in normandie
# No country detected in pommes bretagne
# No country detected in alaska
# No country detected in pommes de terre union europeenne
# No country detected in langue de boeuf non union europeenne
# No country detected in viande origine u e
# No country detected in poulet origine europeenne
# No country detected in fao 51 fao 57 fao 51 3 fao 51 4 fao 57 1
# No country detected in antilles
# No country detected in antilles
# No country detected in bateau margritic
# No country detected in thon albacore
# No country detected in ile maurice
# No country detected in thon blanc germon
# No country detected in thon blanc germon
# No country detected in saumon atlantique
# No country detected in zone de peche mediterranee
# No country detected in ocean atlantique
# No country detected in thon albacore
# No country detected in ocean pacifique centre ouest
# No country detected in sardines sardinops sagax ocean pacifique
# No country detected in europe
# No country detected in import
# No country detected in u e
# No country detected in parmigiano reggiano aop
# No country detected in europe
# No country detected in u e
# No country detected in communaute europeenne
# No country detected in normandie
# No country detected in moules du pacifique
# No country detected in amerique du sud
# No country detected in matiere premiere d importation
# No country detected in atlantique centre ouest fao 31
# No country detected in canard origine union europeenne
# No country detected in ocean pacifique
# No country detected in fr 01 159 002 ce emb 01159b
# No country detected in atlantique
# No country detected in sel de guerande
# No country detected in porc union europeenne
# No country detected in ocean pacifique
# No country detected in ocean pacifique
# No country detected in ocean pacifique
# No country detected in colin d alaska theragra chalcogramma ocean pacifique
# No country detected in colin d alaska
# No country detected in lettre a chair de poisson blanc lettre b chair d encornet geant
# No country detected in ocean pacifique
# No country detected in viande bovine origine union europeenne
# No country detected in ocean pacifique fao 71
# No country detected in huiles d olive union europeenne
# No country detected in huiles d olive union europeenne
# No country detected in laiteries du cotentin
# No country detected in normandie
# No country detected in comte aop fromage de chevre de la drome basilic de provence
# No country detected in hors union europeenne
# No country detected in soja francais
# No country detected in europe
# No country detected in amerique latine
# No country detected in amerique latine
# No country detected in volaille 100 francaise
# No country detected in volaille 100 francaise
# No country detected in normandie 30km autour de la laiterie
# No country detected in 100 noisettes
# No country detected in provence
# No country detected in bourgogne
# No country detected in chairs d escargots de bourgogne helix pomatia linne union europeenne
# No country detected in cultive aux pays bas
# No country detected in picardie beauce flandre
# No country detected in bolets jaunes boletus luteus pleurotes en huitre pleurotus ostreatus champignons de paris psalliota bispora pholiotes pholiota nameko mutabilis lentins de chene lentinus edodes cepes boletus edulis et groupe relatif bolets bai boletus badius
# No country detected in alaska ocean pacifique
# No country detected in alaska ocean pacifique
# No country detected in truffe blanche d ete tuber aestivum
# No country detected in colin d alaska
# No country detected in ocean pacifique
# No country detected in viande bovine francaise gouda des pays bas
# No country detected in ocean pacifique
# No country detected in fao 61 fao 67
# No country detected in lait de normandie
# No country detected in normandie
# No country detected in importation
# No country detected in sardines sardina pilchardus
# No country detected in amerique du sud
# No country detected in union europeenne amerique du sud
# No country detected in ocean pacifique
# No country detected in viande de porc union europeenne
# No country detected in importacion
# No country detected in viande porcine francaise pates oeufs et creme proviennent de union europeenne
# No country detected in importation
# No country detected in produit d importation
# No country detected in produit d importation
# No country detected in import
# No country detected in importation
# No country detected in importation
# No country detected in produit d importation
# No country detected in produit d importation
# No country detected in bretagne
# No country detected in bretagne
# No country detected in antilles
# No country detected in antilles
# No country detected in antilles
# No country detected in trinidad
# No country detected in bretagne
# No country detected in franche comte
# No country detected in flandres
# No country detected in 76191 betteville 76660 fresnoy folny
# No country detected in dordogne
# No country detected in dordogne 24430 marsac
# No country detected in union europeenne hors union europeenne
# No country detected in u e et non u e
# No country detected in issus de l agriculture biologique
# No country detected in bretagne
# No country detected in lait biologique francais
# No country detected in porc bretagne
# No country detected in provence var
# No country detected in parc naturel du haut languedoc
# No country detected in agriculture biologique
# No country detected in sucre de canne d amerique du sud
# No country detected in mayenne
# No country detected in raifort d alsace
# No country detected in asie cee
# No country detected in fabrication maison
# No country detected in val d eurre
# No country detected in sud ouest
# No country detected in sud ouest
# No country detected in cultives dans les landes produit de la ce
# No country detected in antilles
# No country detected in antilles
# No country detected in import
# No country detected in issus de l agriculture biologique
# No country detected in gironde
# No country detected in cotes du roussillon
# No country detected in maury roussillon
# No country detected in compiegne
# No country detected in lieu alaska
# No country detected in colin d alaska ocean pacifique
# No country detected in fao 71 fao 57 fao 51 fao 87 fao 41
# No country detected in bresse
# No country detected in laiterie cooperative etrez 01340 etrez
# No country detected in viande francaise
# No country detected in union europeenne hors union europeenne
# No country detected in mediterranee
# No country detected in savoie
# No country detected in bassin mediterraneen amerique latine afrique du sud
# No country detected in bassin mediterraneen amerique latine afrique du sud
# No country detected in goyave des antilles
# No country detected in antilles
# No country detected in hors d union europeenne
# No country detected in piment jalapeno
# No country detected in 64800 beuste
# No country detected in atlantique nord
# No country detected in montagne
# No country detected in non indique
# No country detected in recette heio
# No country detected in francce
# No country detected in antilles
# No country detected in u e non u e
# No country detected in languedoc roussillon pyrenees orientales
# No country detected in loire atlantique
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in mouilleron en pareds
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in colin d alaska merlu blanc
# No country detected in thon listao colin d alaska
# No country detected in colin d alaska homard americain homarus americanus
# No country detected in colin d alaska merlu blanc
# No country detected in mont ventoux vallee du rhone
# No country detected in importation 28630 mignieres
# No country detected in importation
# No country detected in importation
# No country detected in importation
# No country detected in blaye bordeaux
# No country detected in atlantique nord ouest pays nordiques
# No country detected in ocean pacifique
# No country detected in selectionnes dans le monde entier
# No country detected in saint emilion bordelais
# No country detected in bretagne
# No country detected in antilles
# No country detected in mornant
# No country detected in mornant
# No country detected in saint marcel les valence
# No country detected in saint marceles les valence
# No country detected in vendee
# No country detected in guerande
# No country detected in virazeil
# No country detected in viande d origine francaise
# No country detected in normandie paturage du cotentin
# No country detected in val de loire
# No country detected in champignons eau sel
# No country detected in val de loire
# No country detected in val de loire
# No country detected in alaska
# No country detected in piment d espelette pyrenees atlantiques
# No country detected in ce
# No country detected in normandie
# No country detected in monde
# No country detected in roussillon
# No country detected in champagne
# No country detected in pyrenees
# No country detected in amerique du sud asie
# No country detected in poulet fermier du gers
# No country detected in lait de dordogne
# No country detected in corse
# No country detected in bourgogne
# No country detected in picardie
# No country detected in importation
# No country detected in fao 51
# No country detected in amerique du sud amerique centrale
# No country detected in antilles francaises
# No country detected in bordelais
# No country detected in ardeche
# No country detected in lait de vache
# No country detected in bretagne
# No country detected in fao 61 fao 67
# No country detected in ocean atlantique
# No country detected in agen
# No country detected in atlantique
# No country detected in non indique
# No country detected in cachuete d importation
# No country detected in origine u e
# No country detected in origine u e
# No country detected in igp riz de camargue
# No country detected in elabore et conditionne aux pays bas
# No country detected in viande union europeenne
# No country detected in amerique latine europe
# No country detected in beurre aop charentes poitou
# No country detected in elabore aux pays bas
# No country detected in europe
# No country detected in amerique latine
# No country detected in ile de re
# No country detected in franche comte
# No country detected in colin d alaska theragra chalcogramma
# No country detected in porc union europeenne
# No country detected in andes
# No country detected in alaska
# No country detected in porc fermier francais
# No country detected in importation
# No country detected in importation
# No country detected in importation
# No country detected in importatins
# No country detected in ocean atlantique
# No country detected in ocean pacifique
# No country detected in charenton
# No country detected in marie galante antilles
# No country detected in beaumont de lomagne
# No country detected in riz laos eau fraiche naturelle du laos
# No country detected in soultzmatt
# No country detected in aveyron
# No country detected in aquitaine
# No country detected in sud ouest
# No country detected in sud ouest
# No country detected in auvergne
# No country detected in orleanais
# No country detected in lait de bretagne
# No country detected in normandie
# No country detected in savoie
# No country detected in 73110 farochette savoie
# No country detected in le mont dore
# No country detected in roussillon
# No country detected in pays basque
# No country detected in peaugres
# No country detected in peaugres
# No country detected in ardeche
# No country detected in lorraine
# No country detected in lorraine
# No country detected in general mills
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne hors union europeenne
# No country detected in non union europeenne
# No country detected in ab
# No country detected in alaska
# No country detected in lau balagnas
# No country detected in lau balagnas 65 bruges 64 esterencuby 64
# No country detected in poitou charentes
# No country detected in coteaux du languedoc aoc
# No country detected in provence
# No country detected in 451110 saint martin d abbat
# No country detected in provence
# No country detected in porc origine europe
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in swaziland
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in laos
# No country detected in girona
# No country detected in saint thibault des vignes
# No country detected in alsace
# No country detected in saverne
# No country detected in import
# No country detected in union europeenne hors union europeenne
# No country detected in union europeenne hors union europeenne
# No country detected in champagne
# No country detected in corse
# No country detected in corse
# No country detected in corse
# No country detected in bretagne
# No country detected in 91230 wissous
# No country detected in andiran
# No country detected in pommes francaises
# No country detected in francaise
# No country detected in produit importe
# No country detected in pyrenees ariegeoises
# No country detected in bergues
# No country detected in 49360 maulevrier
# No country detected in maulevrier maine et loire pays de la loire
# No country detected in la grande nillere
# No country detected in bassin mediterraneen
# No country detected in roche des ecrins
# No country detected in antilles
# No country detected in antilles
# No country detected in morbihan bretagne
# No country detected in caraibes
# No country detected in sud ouest
# No country detected in vaucluse drome provencale
# No country detected in amerique latine europe
# No country detected in amerique latine europe
# No country detected in ce hors ce
# No country detected in bordeaux sarl de torrefaction
# No country detected in loire
# No country detected in indre et loire
# No country detected in voges
# No country detected in bassin de l adour aop
# No country detected in pays basque
# No country detected in non connue
# No country detected in bretagne
# No country detected in viande de porc union europeenne
# No country detected in communaute europeenne
# No country detected in normandie
# No country detected in normandie
# No country detected in baratte en normandie
# No country detected in baratte en normandie
# No country detected in normandie
# No country detected in baratte en normandie
# No country detected in creme de normandie
# No country detected in normandie
# No country detected in bordelais
# No country detected in sicile
# No country detected in macedoine
# No country detected in saumon atlantique colin d alaska
# No country detected in charente
# No country detected in haute savoie
# No country detected in beauregard vendon
# No country detected in lorraine
# No country detected in alpes de haute provence
# No country detected in atlantique nord
# No country detected in mer
# No country detected in sao tome
# No country detected in importation
# No country detected in amerique du sud
# No country detected in union europeenne non union europeenne
# No country detected in saint domingue
# No country detected in amerique latine
# No country detected in cotes du roussillon villages
# ...
# No country detected in holland
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in eu
# No country detected in grande bretagne
# No country detected in kent east anglia
# No country detected in oeufs de poules elevees en plein air
# No country detected in more than one country
# No country detected in eu non eu
# No country detected in shri lanka
# No country detected in great britain
# No country detected in bourgogne
# No country detected in california
# No country detected in griekenland
# No country detected in ellada
# No country detected in e u
# No country detected in ellada
# No country detected in crete
# No country detected in mesologgi ellada
# No country detected in pacific ocean
# No country detected in belgie
# No country detected in non union europeenne union europeenne
# No country detected in pont saint pierre normandie eure
# No country detected in europe
# No country detected in nl
# No country detected in source clos de l abbaye
# No country detected in colruytgroup
# No country detected in atlantique nord
# No country detected in porc union europeenne
# No country detected in ocean pacifique fao 61 fao 67
# No country detected in viande de porc union europeenne
# No country detected in ce hors ce
# No country detected in lembeke
# No country detected in asie
# No country detected in belique houblon
# No country detected in normandie
# No country detected in non eu agriculture
# No country detected in non union europeenne
# No country detected in eu
# No country detected in hors ce
# No country detected in benelux
# No country detected in viande d europe
# No country detected in union europeenne hors union europeenne
# No country detected in eu
# No country detected in cacao amerique latine
# No country detected in amerique latine
# No country detected in ardenne belge
# No country detected in hollande
# No country detected in exploitation snoeck
# No country detected in fao 21 atlantique nord ouest
# No country detected in belgie
# No country detected in villers le bouillet
# No country detected in vale do baixo mondego
# No country detected in nao especificada na embalagem
# No country detected in sud de l europe
# No country detected in cabeca do velho
# No country detected in nao especificada na embalagem
# No country detected in nao especificado na embalagem
# No country detected in espanha
# No country detected in monde entier
# No country detected in amerique du sud
# No country detected in oceano atlantico nordeste fao n 27
# No country detected in oceano atlantico nordeste fao n 27
# No country detected in uniao europeia
# No country detected in nao especificada na embalagem
# No country detected in vietname
# No country detected in amerique du sud
# No country detected in danmark
# No country detected in danmark
# No country detected in eu
# No country detected in union europeenne hors unioneuropeenne
# No country detected in danmark
# No country detected in ontario
# No country detected in ontario
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in north east atlantic fao 27
# No country detected in north east atlantic fao 27
# No country detected in polska
# No country detected in eu
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in polska
# No country detected in fao 27
# No country detected in polska
# No country detected in poska
# No country detected in montreal
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in europai unio
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in magyarorszag
# No country detected in zuid afrika
# No country detected in hors union europeenne
# No country detected in afrique
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in ile maurice
# No country detected in fao 34
# No country detected in fao 34
# No country detected in eau fruitee gareifiee
# No country detected in cote d ivoire
# No country detected in tunis
# No country detected in turkei
# No country detected in normandie
# No country detected in bretagne
# No country detected in saudia
# No country detected in uae
# No country detected in uae
# No country detected in dubai uae
# No country detected in sainte claire quebec
# No country detected in prc
# No country detected in ocean pacifique
# No country detected in ocean pacifique fao 61
# No country detected in west indies
# No country detected in ySHrAl
# No country detected in izrail'
# No country detected in bt ym ySHrAl
# No country detected in ySHrAl
# No country detected in sverige
# No country detected in fao 27
# No country detected in tappet i sverige tappet i norge
# No country detected in guatamala
# No country detected in ocean pacifique alaska
# No country detected in sources de soultzmatt f 68570
# No country detected in keniia
# No country detected in geneve
# No country detected in europa amerika asien
# No country detected in montagnes suisses
# No country detected in europe northamerica
# No country detected in europa
# No country detected in asien
# No country detected in europa
# No country detected in moldavien
# No country detected in swasiland
# No country detected in polska
# No country detected in ocean pacifique alaska
# No country detected in pate de cacao d afrique de l ouest
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in afrique de l ouest
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in afrique de l ouest amerique du sud
# No country detected in pacifique
# No country detected in viande de porc union europeenne
# No country detected in viande 100 filet de poulet
# No country detected in source hepar vosges
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in viande de porc union europeenne
# No country detected in afrique de l ouest amerique du sud
# No country detected in pate de cacao d afrique de l ouest
# No country detected in pacifique
# No country detected in europe
# No country detected in ocean pacifique
# No country detected in alaska
# No country detected in amerique du sud europe
# No country detected in amerique centrale amerique du sud europe
# No country detected in alaska
# No country detected in sudamerika
# No country detected in amerique amerique centrale amerique du sud
# No country detected in espacemediterrane
# No country detected in afrique asie
# No country detected in etranger
# No country detected in ocean pacifique
# No country detected in migros
# No country detected in pays alpin
# No country detected in pays alpin
# No country detected in pays alpin
# No country detected in pays alpin
# No country detected in europe
# No country detected in eu
# No country detected in europe amerique du sud
# No country detected in europa
# No country detected in switzerlandi
# No country detected in sudamerica
# No country detected in sudamerica
# No country detected in afrique asie
# No country detected in europe
# No country detected in piemont
# No country detected in cracker cracker con riso soffiato
# No country detected in sicile
# No country detected in sicile
# No country detected in communaute europeenne
# No country detected in eu
# No country detected in union europeene
# No country detected in eu e non eu
# No country detected in eu
# No country detected in europe
# No country detected in eu
# No country detected in fao 51 fao 57
# No country detected in colfiorito perugia
# No country detected in 100 latte di alto adige
# No country detected in piemont
# No country detected in sicile
# No country detected in fao 34
# No country detected in germania
# No country detected in repubblica ceca
# No country detected in germania
# No country detected in produit et emballe par valcolatte
# No country detected in produit et emballe par valcolatte
# No country detected in sudtirol aldein
# No country detected in raisin grape
# No country detected in offida ap
# No country detected in trentin calabre
# No country detected in basilic genois genes
# No country detected in viande italienne
# No country detected in vinaigre balsamique de modene igp fromage grana padano aop fromage pecorino romano aop
# No country detected in vinaigre balsamique de modene igp fromage grana padano aop fromage pecorino romano aop
# No country detected in tomates 100 italiennes
# No country detected in tomates 100 italiennes
# No country detected in viande 100 europeenne
# No country detected in fromages italiens aop
# No country detected in educloranti gomma base stabilizzatori aromi
# No country detected in nederland
# No country detected in mer du nord
# No country detected in quebec
# No country detected in alicante
# No country detected in espanha
# No country detected in espanha
# No country detected in point vert triman
# No country detected in nueces de california
# No country detected in turquia
# No country detected in tarragona
# No country detected in ocean atlantique sud ouest
# No country detected in ocean atlantique sud ouest
# No country detected in espanha
# No country detected in turquia
# No country detected in turquia
# No country detected in turquia
# No country detected in turquia
# No country detected in madrid
# No country detected in oceano atlantico nordeste
# No country detected in fao27 atlantico nordeste subzona va
# No country detected in cacahuetes estados unidos
# No country detected in no especificado
# No country detected in turquia
# No country detected in valencia spane
# No country detected in origen de la leche desconocido envasado en vilalba lugo
# No country detected in atlantico sureste
# No country detected in ocean pacifique fao 87
# No country detected in fao 34
# No country detected in zona atlantica fad27
# No country detected in carnicas munoz sanchez s l tendilla guadalajara
# No country detected in navarra
# No country detected in california estados unidos
# No country detected in turquia
# No country detected in turquia
# No country detected in cantabria
# No country detected in espanha
# No country detected in nao especificada na embalagem
# No country detected in agricultura eu
# No country detected in turquia
# No country detected in holland
# No country detected in segovia orejana
# No country detected in elche alicante
# No country detected in sud afrika
# No country detected in cacao costa de marfil
# No country detected in cantabria extremadura
# No country detected in cantabria extremadura
# No country detected in cuenca
# No country detected in manilva malaga
# No country detected in valencia
# No country detected in la coruna
# No country detected in leche
# No country detected in turquia
# No country detected in almendras estados unidos
# No country detected in barcelona
# No country detected in viande porcine union europeenne
# No country detected in viande union europeenne
# No country detected in u e
# No country detected in colin alaska ocean pacifique
# No country detected in thon albacore
# No country detected in viande porcine union europeenne
# No country detected in saint martin des entrees
# No country detected in colin d alaska theragra chalcogramma
# No country detected in saumon salmo salar
# No country detected in colin d alaska
# No country detected in colin d alaska
# No country detected in importation
# No country detected in viande porcine union europeenne
# No country detected in lettre a colin d alaska theragra chalcogramma lettre b merlu merluccius spp lettre c hoki macruronus spp lettre d merlan bleu micromesistius spp
# No country detected in viande porcine union europeenne
# No country detected in murcia
# No country detected in prague republique tcheque
# No country detected in czech
# No country detected in czech republic tschechische republik
# No country detected in fao 27
# No country detected in serbiia
# No country detected in turkiye
# No country detected in cote d ivoire
# No country detected in cacao de cote d ivoire
# No country detected in cote d ivoire
# No country detected in tatlandiricilar sakiz mayasi renklendirici aroma vericiler kivam arttirici
# No country detected in turkiye
# No country detected in kavacik beykoy istanbul
# No country detected in turkei
# No country detected in griekenland
# No country detected in nederland
# No country detected in eu
# No country detected in u e
# No country detected in nederland
# No country detected in holland amersfoort europe
# No country detected in holland
# No country detected in holland
# No country detected in non renseignee
# No country detected in nederlands
# No country detected in inconnue
# No country detected in non indique
# No country detected in hawai
# No country detected in nederland
# No country detected in made in eu
# No country detected in non eu
# No country detected in agriculture non europeenne
# No country detected in oceano pacifico
# No country detected in hollande
# No country detected in limburg
# No country detected in kitai
# No country detected in nl
# No country detected in holland
# No country detected in eu
# No country detected in nederland
# No country detected in malaysie
# No country detected in eu
# No country detected in colin d alaska
# No country detected in lazio roma
# No country detected in europe
# No country detected in ocean pacifique
# No country detected in tailande
# No country detected in praethsaithy
# No country detected in japanese
# No country detected in philippine
# No country detected in v'etnam
# No country detected in v'etnam
# No country detected in spanyolorszag
# No country detected in spanyolorszag
# No country detected in olaszorszag
# No country detected in olaszorszag
# No country detected in olaszorszag
# No country detected in alpes
# No country detected in amerique du sud
# No country detected in alaska
# No country detected in eu nicht eu landwirtschaft
# No country detected in eu
# No country detected in eu nicht eu landwirtschaft
# No country detected in eu nicht eu landwirtschaft
# No country detected in eu nicht eu landwirtschaft
# No country detected in eu nicht eu landwirtschaft
# No country detected in turkei
# No country detected in eu
# No country detected in eu
# No country detected in niederosterreich
# No country detected in eau des alpes
# No country detected in imported unknown
# No country detected in czech republic imported unknown
# No country detected in imported unknown
# No country detected in imported unknown
# No country detected in imported unknown
# No country detected in australian
# No country detected in imported unknown
# No country detected in austrailan imported
# No country detected in unknown
# No country detected in imported unknown
# No country detected in imported unknown
# No country detected in west country british
# No country detected in cote d ivoire
# No country detected in flaxieu bugey ain
# No country detected in polska

# %%
print_random(DATA_CLEANED[DATA_CLEANED["origins_tags"].str.len() != 0 ]["origins_tags"], 10)
# Out:
# 208194    [european union]
# 309193           [morocco]
# 228946            [france]
# 224712            [france]
# 219446            [france]
# 311850           [ecuador]
# 299955          [colombia]
# 308617             [china]
# 318686     [united-states]
# 307274             [spain]
# Name: origins_tags, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[DATA_CLEANED["origins_tags"].str.len() == 0])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 300901, 93.81%
# Number of value removed = 2282, 0.71%

# %% [markdown]
# Cette fois le nombre de lignes non traitées est plus important,
# mais il est compliqué d'aller plus loin

# %% [markdown]
# ### Nettoyage du nitriscore
# Le nutriscore doit être une lettre entre a et e
# je vérifie que la valeur renseignée est un str entre a et e en ignorant la casse

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["nutrition_grade_fr"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 99562, 31.04%

# %%
DATA_CLEANED["nutrition_grade_fr"] = DATA["nutrition_grade_fr"].apply(str_in, 
                                                                      args=([['a','b','c','d','e']]), 
                                                                      ignore_case=True)

# %%
print_random(DATA_CLEANED[pd.notnull(DATA_CLEANED["nutrition_grade_fr"])]["nutrition_grade_fr"], 10)
# Out:
# 97446     e
# 233715    d
# 181509    b
# 85983     a
# 232200    b
# 157848    c
# 130170    d
# 181063    c
# 244968    c
# 152953    a
# Name: nutrition_grade_fr, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["nutrition_grade_fr"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 99562, 31.04%
# Number of value removed = 0, 0.00%

# %% [markdown]
# Tous les nutriscores sont correctement renseignés

# %% [markdown]
# ### Nettoyage du nombre d'additifs
# additives_n doit être un nombre entier

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["additives_n"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 71833, 22.39%

# %%
DATA_CLEANED['additives_n'] = DATA['additives_n'].apply(is_int)

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["additives_n"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 71833, 22.39%
# Number of value removed = 0, 0.00%

# %% [markdown]
# Toutes les valeurs sont correctes

# %% [markdown]
# ### Nettoyage des variables de type float :
# Elles doivent être un float ou un int
# - carbon-footprint_100g
# - energy_100g
#
# NB : le nombre de valeurs non nulles est très faible pour l'empreinte carbone...

# %%
for variable in ["carbon-footprint_100g", "energy_100g"] :
    print('-'*50)
    print(f"Nettoyage de la variable {variable}")
    nullvalue_before = len(DATA[pd.isnull(DATA[variable])])
    print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
    
    DATA_CLEANED[variable] = DATA[variable].apply(is_float)
    
    nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED[variable])])
    print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
    print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# --------------------------------------------------
# Nettoyage de la variable carbon-footprint_100g
# Missing value in code before cleaning = 320504, 99.92%
# Missing value in code after cleaning = 320504, 99.92%
# Number of value removed = 0, 0.00%
# --------------------------------------------------
# Nettoyage de la variable energy_100g
# Missing value in code before cleaning = 59659, 18.60%
# Missing value in code after cleaning = 59659, 18.60%
# Number of value removed = 0, 0.00%

# %% [markdown]
# ### Nettoyage des variables représentants les apports pour 100g
# les variables 'fat_100g', 'saturated-fat_100g', 'fruits-vegetables-nuts_100g', 'sodium_100g', 'sugar_100g' doivent être des floats compris entre 0 et 100.
# Si les valeurs ne sont pas dans la gamme 0-100, elles seront considérées comme abérrante et remplacées par np.NaN

# %%
for variable in ['fat_100g', 'saturated-fat_100g', 'fruits-vegetables-nuts_100g', 'sodium_100g', 'sugars_100g' ] :
    print('-'*50)
    print(f"Nettoyage de la variable {variable}")
    nullvalue_before = len(DATA[pd.isnull(DATA[variable])])
    print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
    
    DATA_CLEANED[variable] = DATA[variable].apply(is_float)
    DATA_CLEANED[variable] = DATA_CLEANED[variable].apply(is_lower, target=100)
    DATA_CLEANED[variable] = DATA_CLEANED[variable].apply(is_higher, target=0)
    
    nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED[variable])])
    print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
    print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# --------------------------------------------------
# Nettoyage de la variable fat_100g
# Missing value in code before cleaning = 76881, 23.97%
# 714.29 is higher than the target 100
# 380.0 is higher than the target 100
# 101.0 is higher than the target 100
# 105.0 is higher than the target 100
# Missing value in code after cleaning = 76885, 23.97%
# Number of value removed = 4, 0.00%
# --------------------------------------------------
# Nettoyage de la variable saturated-fat_100g
# Missing value in code before cleaning = 91218, 28.44%
# 175.38 is higher than the target 100
# 210.0 is higher than the target 100
# 550.0 is higher than the target 100
# Missing value in code after cleaning = 91221, 28.44%
# Number of value removed = 3, 0.00%
# --------------------------------------------------
# Nettoyage de la variable fruits-vegetables-nuts_100g
# Missing value in code before cleaning = 317736, 99.05%
# Missing value in code after cleaning = 317736, 99.05%
# Number of value removed = 0, 0.00%
# --------------------------------------------------
# Nettoyage de la variable sodium_100g
# Missing value in code before cleaning = 65309, 20.36%
# 342.857 is higher than the target 100
# 307.692 is higher than the target 100
# 129.032 is higher than the target 100
# 281.25 is higher than the target 100
# 234.2 is higher than the target 100
# 800.0 is higher than the target 100
# 857.143 is higher than the target 100
# 708.333 is higher than the target 100
# 432.432 is higher than the target 100
# 338.028 is higher than the target 100
# 519.048 is higher than the target 100
# 965.517 is higher than the target 100
# 448.485 is higher than the target 100
# 262.5 is higher than the target 100
# 266.667 is higher than the target 100
# 266.667 is higher than the target 100
# 266.667 is higher than the target 100
# 266.667 is higher than the target 100
# 266.667 is higher than the target 100
# 266.667 is higher than the target 100
# 125.0 is higher than the target 100
# 238.095 is higher than the target 100
# 1400.0 is higher than the target 100
# 1200.0 is higher than the target 100
# 166.078 is higher than the target 100
# 25320.0 is higher than the target 100
# 657.143 is higher than the target 100
# 400.0 is higher than the target 100
# 150.0 is higher than the target 100
# 116.667 is higher than the target 100
# 109.0 is higher than the target 100
# 117.165354330709 is higher than the target 100
# 176.471 is higher than the target 100
# 366.141732283465 is higher than the target 100
# Missing value in code after cleaning = 65343, 20.37%
# Number of value removed = 34, 0.01%
# --------------------------------------------------
# Nettoyage de la variable sugars_100g
# Missing value in code before cleaning = 75801, 23.63%
# 134.0 is higher than the target 100
# 110.71 is higher than the target 100
# 166.67 is higher than the target 100
# 104.0 is higher than the target 100
# 105.0 is higher than the target 100
# 103.5 is higher than the target 100
# 103.5 is higher than the target 100
# 103.5 is higher than the target 100
# 103.5 is higher than the target 100
# 103.0 is higher than the target 100
# 3520.0 is higher than the target 100
# 100.8 is higher than the target 100
# -1.2 is lower than the target 0
# -0.8 is lower than the target 0
# -3.57 is lower than the target 0
# -6.67 is lower than the target 0
# -6.25 is lower than the target 0
# -17.86 is lower than the target 0
# -0.1 is lower than the target 0
# Missing value in code after cleaning = 75820, 23.64%
# Number of value removed = 19, 0.01%

# %% [markdown]
# ### Nettoyage catégories pnns
# les valeurs doivent être de type str,
# les valeurs unknown sont remplacées par np.NaN
# Les espaces sont remplacés par des '_'
# le texte est passé en minuscules uniquement
# Il s'avère qu'initialement des '-' peuvent se placer à la place des espaces, suppression.

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["pnns_groups_1"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 229259, 71.47%

# %%
DATA_CLEANED["pnns_groups_1"] = DATA["pnns_groups_1"].apply(is_str).apply(lower_case).apply(str_replace, args=("-", " ")).apply(str_replace, args=(" ", "_")).apply(remove_str, args=("unknown",))

# %%
print_random(DATA_CLEANED[pd.notnull(DATA_CLEANED["pnns_groups_1"])]["pnns_groups_1"], 10)
# Out:
# 174898       cereals_and_potatoes
# 216215    milk_and_dairy_products
# 262114              sugary_snacks
# 205367    milk_and_dairy_products
# 196788              sugary_snacks
# 233505             fish_meat_eggs
# 255277                  beverages
# 282889       cereals_and_potatoes
# 225018             fish_meat_eggs
# 178170    milk_and_dairy_products
# Name: pnns_groups_1, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["pnns_groups_1"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 251883, 78.52%
# Number of value removed = 22624, 7.05%

# %%
nullvalue_before = len(DATA[pd.isnull(DATA["pnns_groups_2"])])
print(f"Missing value in code before cleaning = {nullvalue_before}, {nullvalue_before/size*100:.2f}%")
# Out:
# Missing value in code before cleaning = 226281, 70.54%

# %%
DATA_CLEANED["pnns_groups_2"] = DATA["pnns_groups_2"].apply(is_str).apply(lower_case).apply(str_replace, args=("-", " ")).apply(str_replace, args=(" ", "_")).apply(remove_str, args=("unknown",))

# %%
print_random(DATA_CLEANED[pd.notnull(DATA_CLEANED["pnns_groups_2"])]["pnns_groups_2"], 10)
# Out:
# 311299               vegetables
# 219089                ice_cream
# 237493             fruit_juices
# 218358           one_dish_meals
# 252031     dressings_and_sauces
# 240674                   sweets
# 270065                  cereals
# 199364      alcoholic_beverages
# 264540                  legumes
# 309562    non_sugared_beverages
# Name: pnns_groups_2, dtype: object

# %%
nullvalue_cleaned = len(DATA_CLEANED[pd.isnull(DATA_CLEANED["pnns_groups_2"])])
print(f"Missing value in code after cleaning = {nullvalue_cleaned}, {nullvalue_cleaned/size*100:.2f}%")
print(f"Number of value removed = {nullvalue_cleaned - nullvalue_before}, {(nullvalue_cleaned - nullvalue_before)/size*100:.2f}%")
# Out:
# Missing value in code after cleaning = 248905, 77.60%
# Number of value removed = 22624, 7.05%

# %% [markdown]
# Un nombre important de valeurs ont été supprimées, correspondant aux valeurs unknown

# %% [markdown]
# ### Détection des doublons

# %%
effectifs_code = DATA_CLEANED["code"].value_counts()
print(f"Nombre de doublons détectés à partir du code : {len(effectifs_code[effectifs_code > 1])}")
# Out:
# Nombre de doublons détectés à partir du code : 0

# %% [markdown]
# ### Suppression des doublons

# %% [markdown]
# je crée volontairement un doublon pour le développement des fonctions

# %%
#dup = DATA_CLEANED[DATA_CLEANED["code"] == "8712100872044"]
#DATA_DUP = pd.concat([DATA_CLEANED, dup], axis=0, ignore_index=True)
#effectifs_code = DATA_DUP["code"].value_counts()

# %%
#print(len(DATA_DUP))
#for code in effectifs_code[effectifs_code > 1].index :
#    print(code)
#    duplicates = DATA_DUP[DATA_DUP["code"] == code ]
#    DATA_DUP.drop(DATA_DUP[DATA_DUP["code"] == code].index, inplace=True)
#    #print(len(DATA_DUP))
#    #print(duplicates)
#    new_rows = merge_rows(duplicates)
#    print(new_rows)

# %%
effectifs_code = DATA_CLEANED["code"].value_counts()
for code in effectifs_code[effectifs_code > 1].index :
    print(f"{code} is duplicated, merge all rows")
    duplicates = DATA_CLEANED[DATA_CLEANED["code"] == code ]
    DATA_CLEANED.drop(DATA_CLEANED[DATA_CLEANED["code"] == code].index, inplace=True)
    new_row = merge_rows(duplicates)
    DATA_CLEANED = pd.concat([DATA_CLEANED, new_row], axis=0, ignore_index=True)

# %% [markdown]
# ### Conversion des variables de type list en str
# Pour la sauvegarde il est préférable de repasser les varibales de type list en str

# %%
for col in ['categories_tags', 'origins_tags', 'manufacturing_places_tags'] :
    DATA_CLEANED[col] = DATA_CLEANED[col].apply(list2str)

# %% [markdown]
# ### Sauvegarde de la base de données nettoyer
# sauvegarde au format csv délimité par ";"
# et au format pickle

# %%
DATA_CLEANED.to_csv("database_cleaned.csv", sep=";", index=False)
with open("database_cleaned.pkl", "wb") as ofile :
    pickle.dump(DATA_CLEANED, ofile)
